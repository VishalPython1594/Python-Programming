# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("student_placement.xlsx")
df.head()
# Out:
#   experience job_desig   location  salary  placement_count
# 0    1-6 yrs      Data  Ahmedabad    0to3             3914
# 1    1-5 yrs      Data  Ahmedabad    3to6             3365
# 2   7-11 yrs      Data  Ahmedabad  10to15             1301
# 3    0-3 yrs       SEO  Ahmedabad    3to6             1248
# 4    1-4 yrs    Social  Ahmedabad    0to3             2682

# %%
table_2 = pd.read_csv('data.txt',sep='\t')
table_2.head()
# Out:
#    job_desig   location  salary
# 0  Analytics     Mumbai   6to10
# 1  Analytics  Delhi NCR   6to10
# 2     Growth     Mumbai  15to25
# 3  Analytics  Bengaluru   6to10
# 4  Analytics  Delhi NCR  25to50

# %%
table_1 = pd.read_csv("data.csv", sep = ",")
table_1.head()
# Out:
#   experience  job_desig   location  salary  placement_count
# 0    2-4 yrs  Analytics     Mumbai   6to10             4479
# 1   5-10 yrs  Analytics  Delhi NCR   6to10             1969
# 2    3-8 yrs     Growth     Mumbai  15to25             3319
# 3    2-6 yrs  Analytics  Bengaluru   6to10              330
# 4    6-8 yrs  Analytics  Delhi NCR  25to50             2665

# %%
res = pd.concat([table_1,table_2], axis=1)
res.head()
# Out:
#   experience  job_desig   location  salary  placement_count  job_desig  \
# 0    2-4 yrs  Analytics     Mumbai   6to10             4479  Analytics
# 1   5-10 yrs  Analytics  Delhi NCR   6to10             1969  Analytics
# 2    3-8 yrs     Growth     Mumbai  15to25             3319     Growth
# 3    2-6 yrs  Analytics  Bengaluru   6to10              330  Analytics
# 4    6-8 yrs  Analytics  Delhi NCR  25to50             2665  Analytics
#
#     location  salary
# 0     Mumbai   6to10
# 1  Delhi NCR   6to10
# 2     Mumbai  15to25
# 3  Bengaluru   6to10
# 4  Delhi NCR  25to50

# %%
res.to_excel('res.xlsx')
res.to_csv('res.txt',sep=';')

# %%
pd.read_csv('res.txt',sep=';').head()
# Out:
#    Unnamed: 0 experience  job_desig   location  salary  placement_count  \
# 0           0    2-4 yrs  Analytics     Mumbai   6to10             4479
# 1           1   5-10 yrs  Analytics  Delhi NCR   6to10             1969
# 2           2    3-8 yrs     Growth     Mumbai  15to25             3319
# 3           3    2-6 yrs  Analytics  Bengaluru   6to10              330
# 4           4    6-8 yrs  Analytics  Delhi NCR  25to50             2665
#
#   job_desig.1 location.1 salary.1
# 0   Analytics     Mumbai    6to10
# 1   Analytics  Delhi NCR    6to10
# 2      Growth     Mumbai   15to25
# 3   Analytics  Bengaluru    6to10
# 4   Analytics  Delhi NCR   25to50

# %%
dataset = pd.read_excel("student_placement.xlsx", sheet_name="value_data")
dataset
# Out:
#    experience   job_desig   location  salary  placement_count
# 0     2-4 yrs   Analytics     Mumbai   6to10             4479
# 1    5-10 yrs   Analytics  Delhi NCR   6to10             1969
# 2     3-8 yrs      Growth     Mumbai  15to25             3319
# 3     2-6 yrs   Analytics  Bengaluru   6to10              330
# 4     6-8 yrs   Analytics  Delhi NCR  25to50             2665
# 5     2-5 yrs  Consultant  Bengaluru    3to6              314
# 6    5-10 yrs   Analytics    Chennai  10to15             3382
# 7    8-13 yrs    Industry    Chennai  15to25             2922
# 8    5-10 yrs        Data  Bengaluru  15to25             2807
# 9    6-11 yrs        Data     Mumbai   6to10             1176
# 10    0-3 yrs    Business  Bengaluru    3to6              107
# 11   5-10 yrs   Analytics  Delhi NCR  15to25             1989
# 12    3-6 yrs   Analytics  Bengaluru    3to6              190

# %%
print(dataset.values)
print(type(dataset.values))
# Out:
# [['2-4 yrs' 'Analytics' 'Mumbai' '6to10' 4479]
#  ['5-10 yrs' 'Analytics' 'Delhi NCR' '6to10' 1969]
#  ['3-8 yrs' 'Growth' 'Mumbai' '15to25' 3319]
#  ['2-6 yrs' 'Analytics' 'Bengaluru' '6to10' 330]
#  ['6-8 yrs' 'Analytics' 'Delhi NCR' '25to50' 2665]
#  ['2-5 yrs' 'Consultant' 'Bengaluru' '3to6' 314]
#  ['5-10 yrs' 'Analytics' 'Chennai' '10to15' 3382]
#  ['8-13 yrs' 'Industry' 'Chennai' '15to25' 2922]
#  ['5-10 yrs' 'Data' 'Bengaluru' '15to25' 2807]
#  ['6-11 yrs' 'Data' 'Mumbai' '6to10' 1176]
#  ['0-3 yrs' 'Business' 'Bengaluru' '3to6' 107]
#  ['5-10 yrs' 'Analytics' 'Delhi NCR' '15to25' 1989]
#  ['3-6 yrs' 'Analytics' 'Bengaluru' '3to6' 190]]
# <class 'numpy.ndarray'>

# %%
print((dataset.iloc[4,]).values)
# Out:
# ['6-8 yrs' 'Analytics' 'Delhi NCR' '25to50' 2665]

# %%
print((dataset.iloc[:,4]).values)
# Out:
# [4479 1969 3319  330 2665  314 3382 2922 2807 1176  107 1989  190]

# %%
dataset.describe(include='all')
# Out:
#        experience  job_desig   location salary  placement_count
# count          13         13         13     13        13.000000
# unique         10          6          4      5              NaN
# top      5-10 yrs  Analytics  Bengaluru  6to10              NaN
# freq            4          7          5      4              NaN
# mean          NaN        NaN        NaN    NaN      1973.000000
# std           NaN        NaN        NaN    NaN      1440.494996
# min           NaN        NaN        NaN    NaN       107.000000
# 25%           NaN        NaN        NaN    NaN       330.000000
# 50%           NaN        NaN        NaN    NaN      1989.000000
# 75%           NaN        NaN        NaN    NaN      2922.000000
# max           NaN        NaN        NaN    NaN      4479.000000

# %%
print(dataset[['placement_count']].max())
# Out:
# placement_count    4479
# dtype: int64

# %%
print(dataset['placement_count'].max())
# Out:
# 4479

# %%
print(dataset['placement_count'].min())
print(dataset['placement_count'].mean())
print(dataset['placement_count'].median())
print(round(dataset['placement_count'].std()),2)
print(dataset['placement_count'].sum())
print(dataset['placement_count'].count())
# Out:
# 107
# 1973.0
# 1989.0
# 1440 2
# 25649
# 13

# %%
print((dataset['location']).unique())
# Out:
# ['Mumbai' 'Delhi NCR' 'Bengaluru' 'Chennai']

# %%
print((dataset['location']).nunique())
# Out:
# 4

# %%
print((dataset['location']).value_counts())
# Out:
# location
# Bengaluru    5
# Mumbai       3
# Delhi NCR    3
# Chennai      2
# Name: count, dtype: int64

# %%
df = dataset.copy()
df.head()
# Out:
#   experience  job_desig   location  salary  placement_count
# 0    2-4 yrs  Analytics     Mumbai   6to10             4479
# 1   5-10 yrs  Analytics  Delhi NCR   6to10             1969
# 2    3-8 yrs     Growth     Mumbai  15to25             3319
# 3    2-6 yrs  Analytics  Bengaluru   6to10              330
# 4    6-8 yrs  Analytics  Delhi NCR  25to50             2665

# %%
print(df[df.duplicated()])
df[df.duplicated()].shape
# Out:
# Empty DataFrame
# Columns: [experience, job_desig, location, salary, placement_count]
# Index: []
# (0, 5)

# %%
df_without_duplictaes = df.drop_duplicates()
df_without_duplictaes.head
# Out:
# <bound method NDFrame.head of    experience   job_desig   location  salary  placement_count
# 0     2-4 yrs   Analytics     Mumbai   6to10             4479
# 1    5-10 yrs   Analytics  Delhi NCR   6to10             1969
# 2     3-8 yrs      Growth     Mumbai  15to25             3319
# 3     2-6 yrs   Analytics  Bengaluru   6to10              330
# 4     6-8 yrs   Analytics  Delhi NCR  25to50             2665
# 5     2-5 yrs  Consultant  Bengaluru    3to6              314
# 6    5-10 yrs   Analytics    Chennai  10to15             3382
# 7    8-13 yrs    Industry    Chennai  15to25             2922
# 8    5-10 yrs        Data  Bengaluru  15to25             2807
# 9    6-11 yrs        Data     Mumbai   6to10             1176
# 10    0-3 yrs    Business  Bengaluru    3to6              107
# 11   5-10 yrs   Analytics  Delhi NCR  15to25             1989
# 12    3-6 yrs   Analytics  Bengaluru    3to6              190>

# %%
df = pd.read_excel("student_placement.xlsx", sheet_name='data',index_col=4)
df.head()
# Out:
#                 experience job_desig   location  salary
# placement_count
# 3914               1-6 yrs      Data  Ahmedabad    0to3
# 3365               1-5 yrs      Data  Ahmedabad    3to6
# 1301              7-11 yrs      Data  Ahmedabad  10to15
# 1248               0-3 yrs       SEO  Ahmedabad    3to6
# 2682               1-4 yrs    Social  Ahmedabad    0to3

# %%
print(df.index.values)
# Out:
# [3914 3365 1301 1248 2682  330  190  190  190 4541 1893 1969 1993 1173
#  3612  190 2884  190 2884  107  280  314 1473 2807 3241   16 3076 3076
#   921  190 2934 2981 2402  753 1217 1217 2307  871 3382 1783  464  898
#  3612  860  860 2922 1969 2665 1989 1969 1988  193  190 1989 2914 1616
#  4470 3319 4330  191 2676 2574 1970 2059 2665 1969 2574 2906 1730 2827
#   769 2388 1988 1211 3322 3636  772 4479 4167 3848 1167 3838 4840  322
#  3767 1863 3767 2809 2434 3383 5018 1859 1176 1871 4568 1831 4904 3319
#  3319 3441  921  190  190 4448 4011]

# %%
df = pd.read_excel("student_placement.xlsx", sheet_name='data')
df.head()
# Out:
#   experience job_desig   location  salary  placement_count
# 0    1-6 yrs      Data  Ahmedabad    0to3             3914
# 1    1-5 yrs      Data  Ahmedabad    3to6             3365
# 2   7-11 yrs      Data  Ahmedabad  10to15             1301
# 3    0-3 yrs       SEO  Ahmedabad    3to6             1248
# 4    1-4 yrs    Social  Ahmedabad    0to3             2682

# %%
df.head()
# Out:
#            job_desig   location  placement_count
# experience
# 1-6 yrs         Data  Ahmedabad             3914
# 1-5 yrs         Data  Ahmedabad             3365
# 7-11 yrs        Data  Ahmedabad             1301
# 0-3 yrs          SEO  Ahmedabad             1248
# 1-4 yrs       Social  Ahmedabad             2682

# %%
df.reset_index(inplace=True)
df.head()
# Out:
#    level_0  index experience job_desig   location  placement_count
# 0        0      0    1-6 yrs      Data  Ahmedabad             3914
# 1        1      1    1-5 yrs      Data  Ahmedabad             3365
# 2        2      2   7-11 yrs      Data  Ahmedabad             1301
# 3        3      3    0-3 yrs       SEO  Ahmedabad             1248
# 4        4      4    1-4 yrs    Social  Ahmedabad             2682

# %%
df.reset_index(inplace=True,drop=True)
df.head()
# Out:
#    level_0  index experience job_desig   location  placement_count
# 0        0      0    1-6 yrs      Data  Ahmedabad             3914
# 1        1      1    1-5 yrs      Data  Ahmedabad             3365
# 2        2      2   7-11 yrs      Data  Ahmedabad             1301
# 3        3      3    0-3 yrs       SEO  Ahmedabad             1248
# 4        4      4    1-4 yrs    Social  Ahmedabad             2682

# %%
dataset = pd.read_excel("student_placement.xlsx", sheet_name="value_data")
dataset
# Out:
#    experience   job_desig   location  salary  placement_count
# 0     2-4 yrs   Analytics     Mumbai   6to10             4479
# 1    5-10 yrs   Analytics  Delhi NCR   6to10             1969
# 2     3-8 yrs      Growth     Mumbai  15to25             3319
# 3     2-6 yrs   Analytics  Bengaluru   6to10              330
# 4     6-8 yrs   Analytics  Delhi NCR  25to50             2665
# 5     2-5 yrs  Consultant  Bengaluru    3to6              314
# 6    5-10 yrs   Analytics    Chennai  10to15             3382
# 7    8-13 yrs    Industry    Chennai  15to25             2922
# 8    5-10 yrs        Data  Bengaluru  15to25             2807
# 9    6-11 yrs        Data     Mumbai   6to10             1176
# 10    0-3 yrs    Business  Bengaluru    3to6              107
# 11   5-10 yrs   Analytics  Delhi NCR  15to25             1989
# 12    3-6 yrs   Analytics  Bengaluru    3to6              190

# %%
import random

dataset['rand'] = [random.randint(1,10) for i in range(0,dataset.shape[0])]
dataset
# Out:
#    experience   job_desig   location  salary  placement_count  rand
# 0     2-4 yrs   Analytics     Mumbai   6to10             4479    10
# 1    5-10 yrs   Analytics  Delhi NCR   6to10             1969     6
# 2     3-8 yrs      Growth     Mumbai  15to25             3319     7
# 3     2-6 yrs   Analytics  Bengaluru   6to10              330     5
# 4     6-8 yrs   Analytics  Delhi NCR  25to50             2665     5
# 5     2-5 yrs  Consultant  Bengaluru    3to6              314     8
# 6    5-10 yrs   Analytics    Chennai  10to15             3382     1
# 7    8-13 yrs    Industry    Chennai  15to25             2922     4
# 8    5-10 yrs        Data  Bengaluru  15to25             2807     7
# 9    6-11 yrs        Data     Mumbai   6to10             1176     8
# 10    0-3 yrs    Business  Bengaluru    3to6              107     8
# 11   5-10 yrs   Analytics  Delhi NCR  15to25             1989     2
# 12    3-6 yrs   Analytics  Bengaluru    3to6              190     7

# %%
dataset['upper1'] = [lambda u : u.upper() for u in (dataset['location'].values)]
dataset
# Out:
#    experience   job_desig   location  salary  placement_count  rand  \
# 0     2-4 yrs   Analytics     Mumbai   6to10             4479    10
# 1    5-10 yrs   Analytics  Delhi NCR   6to10             1969     6
# 2     3-8 yrs      Growth     Mumbai  15to25             3319     7
# 3     2-6 yrs   Analytics  Bengaluru   6to10              330     5
# 4     6-8 yrs   Analytics  Delhi NCR  25to50             2665     5
# 5     2-5 yrs  Consultant  Bengaluru    3to6              314     8
# 6    5-10 yrs   Analytics    Chennai  10to15             3382     1
# 7    8-13 yrs    Industry    Chennai  15to25             2922     4
# 8    5-10 yrs        Data  Bengaluru  15to25             2807     7
# 9    6-11 yrs        Data     Mumbai   6to10             1176     8
# 10    0-3 yrs    Business  Bengaluru    3to6              107     8
# 11   5-10 yrs   Analytics  Delhi NCR  15to25             1989     2
# 12    3-6 yrs   Analytics  Bengaluru    3to6              190     7
#
# ...

# %%
print(dataset['location'].values)
# Out:
# ['Mumbai' 'Delhi NCR' 'Mumbai' 'Bengaluru' 'Delhi NCR' 'Bengaluru'
#  'Chennai' 'Chennai' 'Bengaluru' 'Mumbai' 'Bengaluru' 'Delhi NCR'
#  'Bengaluru']

# %%
print(type(dataset['location'].values))
# Out:
# <class 'numpy.ndarray'>

# %%
dataset
# Out:
#    experience   job_desig   location  salary  placement_count  rand
# 0     2-4 yrs   Analytics     Mumbai   6to10             4479    10
# 1    5-10 yrs   Analytics  Delhi NCR   6to10             1969     6
# 2     3-8 yrs      Growth     Mumbai  15to25             3319     7
# 3     2-6 yrs   Analytics  Bengaluru   6to10              330     5
# 4     6-8 yrs   Analytics  Delhi NCR  25to50             2665     5
# 5     2-5 yrs  Consultant  Bengaluru    3to6              314     8
# 6    5-10 yrs   Analytics    Chennai  10to15             3382     1
# 7    8-13 yrs    Industry    Chennai  15to25             2922     4
# 8    5-10 yrs        Data  Bengaluru  15to25             2807     7
# 9    6-11 yrs        Data     Mumbai   6to10             1176     8
# 10    0-3 yrs    Business  Bengaluru    3to6              107     8
# 11   5-10 yrs   Analytics  Delhi NCR  15to25             1989     2
# 12    3-6 yrs   Analytics  Bengaluru    3to6              190     7

# %%
dataset['placement_count'] = dataset['placement_count'] - dataset['placement_count']/10
dataset
# Out:
#    experience   job_desig   location  salary  placement_count  rand
# 0     2-4 yrs   Analytics     Mumbai   6to10           4031.1    10
# 1    5-10 yrs   Analytics  Delhi NCR   6to10           1772.1     6
# 2     3-8 yrs      Growth     Mumbai  15to25           2987.1     7
# 3     2-6 yrs   Analytics  Bengaluru   6to10            297.0     5
# 4     6-8 yrs   Analytics  Delhi NCR  25to50           2398.5     5
# 5     2-5 yrs  Consultant  Bengaluru    3to6            282.6     8
# 6    5-10 yrs   Analytics    Chennai  10to15           3043.8     1
# 7    8-13 yrs    Industry    Chennai  15to25           2629.8     4
# 8    5-10 yrs        Data  Bengaluru  15to25           2526.3     7
# 9    6-11 yrs        Data     Mumbai   6to10           1058.4     8
# 10    0-3 yrs    Business  Bengaluru    3to6             96.3     8
# 11   5-10 yrs   Analytics  Delhi NCR  15to25           1790.1     2
# 12    3-6 yrs   Analytics  Bengaluru    3to6            171.0     7

# %%
rows = [f'Row Number {i+1}' for i in range(dataset.shape[0])]
rows
# Out:
# ['Row Number 1',
#  'Row Number 2',
#  'Row Number 3',
#  'Row Number 4',
#  'Row Number 5',
#  'Row Number 6',
#  'Row Number 7',
#  'Row Number 8',
#  'Row Number 9',
#  'Row Number 10',
#  'Row Number 11',
#  'Row Number 12',
#  'Row Number 13']

# %%
dataset['rows'] = rows
dataset
# Out:
#    experience   job_desig   location  salary  placement_count  rand  \
# 0     2-4 yrs   Analytics     Mumbai   6to10           4031.1    10
# 1    5-10 yrs   Analytics  Delhi NCR   6to10           1772.1     6
# 2     3-8 yrs      Growth     Mumbai  15to25           2987.1     7
# 3     2-6 yrs   Analytics  Bengaluru   6to10            297.0     5
# 4     6-8 yrs   Analytics  Delhi NCR  25to50           2398.5     5
# 5     2-5 yrs  Consultant  Bengaluru    3to6            282.6     8
# 6    5-10 yrs   Analytics    Chennai  10to15           3043.8     1
# 7    8-13 yrs    Industry    Chennai  15to25           2629.8     4
# 8    5-10 yrs        Data  Bengaluru  15to25           2526.3     7
# 9    6-11 yrs        Data     Mumbai   6to10           1058.4     8
# 10    0-3 yrs    Business  Bengaluru    3to6             96.3     8
# 11   5-10 yrs   Analytics  Delhi NCR  15to25           1790.1     2
# 12    3-6 yrs   Analytics  Bengaluru    3to6            171.0     7
#
# ...

# %%
dataset.set_index('rows')
# Out:
#               experience   job_desig   location  salary  placement_count  rand
# rows
# Row Number 1     2-4 yrs   Analytics     Mumbai   6to10           4031.1    10
# Row Number 2    5-10 yrs   Analytics  Delhi NCR   6to10           1772.1     6
# Row Number 3     3-8 yrs      Growth     Mumbai  15to25           2987.1     7
# Row Number 4     2-6 yrs   Analytics  Bengaluru   6to10            297.0     5
# Row Number 5     6-8 yrs   Analytics  Delhi NCR  25to50           2398.5     5
# Row Number 6     2-5 yrs  Consultant  Bengaluru    3to6            282.6     8
# Row Number 7    5-10 yrs   Analytics    Chennai  10to15           3043.8     1
# Row Number 8    8-13 yrs    Industry    Chennai  15to25           2629.8     4
# Row Number 9    5-10 yrs        Data  Bengaluru  15to25           2526.3     7
# Row Number 10   6-11 yrs        Data     Mumbai   6to10           1058.4     8
# Row Number 11    0-3 yrs    Business  Bengaluru    3to6             96.3     8
# ...

# %%
rows = [f'row number {i*11}' for i in range(0,dataset.shape[0])]
dataset['rows'] = rows
dataset
# Out:
#    experience   job_desig   location  salary  placement_count  rand  \
# 0     2-4 yrs   Analytics     Mumbai   6to10           4031.1    10
# 1    5-10 yrs   Analytics  Delhi NCR   6to10           1772.1     6
# 2     3-8 yrs      Growth     Mumbai  15to25           2987.1     7
# 3     2-6 yrs   Analytics  Bengaluru   6to10            297.0     5
# 4     6-8 yrs   Analytics  Delhi NCR  25to50           2398.5     5
# 5     2-5 yrs  Consultant  Bengaluru    3to6            282.6     8
# 6    5-10 yrs   Analytics    Chennai  10to15           3043.8     1
# 7    8-13 yrs    Industry    Chennai  15to25           2629.8     4
# 8    5-10 yrs        Data  Bengaluru  15to25           2526.3     7
# 9    6-11 yrs        Data     Mumbai   6to10           1058.4     8
# 10    0-3 yrs    Business  Bengaluru    3to6             96.3     8
# 11   5-10 yrs   Analytics  Delhi NCR  15to25           1790.1     2
# 12    3-6 yrs   Analytics  Bengaluru    3to6            171.0     7
#
# ...

# %%
#dataset.set_index('rows',inplace=True)
dataset


#dataset.drop('upper',axis=1,inplace=True)
dataset

dataset['remarks'] = dataset['placement_count'].apply(lambda p : 'Good' if p>2500 else 'Bad')
dataset

# %%
dataset['Upper'] = dataset['location'].apply(lambda s: s.upper())
dataset
# Out:
#                experience   job_desig   location  salary  placement_count  \
# rows
# row number 0      2-4 yrs   Analytics     Mumbai   6to10           4031.1
# row number 11    5-10 yrs   Analytics  Delhi NCR   6to10           1772.1
# row number 22     3-8 yrs      Growth     Mumbai  15to25           2987.1
# row number 33     2-6 yrs   Analytics  Bengaluru   6to10            297.0
# row number 44     6-8 yrs   Analytics  Delhi NCR  25to50           2398.5
# row number 55     2-5 yrs  Consultant  Bengaluru    3to6            282.6
# row number 66    5-10 yrs   Analytics    Chennai  10to15           3043.8
# row number 77    8-13 yrs    Industry    Chennai  15to25           2629.8
# row number 88    5-10 yrs        Data  Bengaluru  15to25           2526.3
# row number 99    6-11 yrs        Data     Mumbai   6to10           1058.4
# row number 110    0-3 yrs    Business  Bengaluru    3to6             96.3
# row number 121   5-10 yrs   Analytics  Delhi NCR  15to25           1790.1
# ...

# %%
dataset['new'] = dataset[['job_desig','location']].apply(lambda a : str(a[0])[:3] + '-' + str(a[1])[:3],axis=1)
dataset
# Out:
#                experience   job_desig   location  salary  placement_count  \
# rows
# row number 0      2-4 yrs   Analytics     Mumbai   6to10           4031.1
# row number 11    5-10 yrs   Analytics  Delhi NCR   6to10           1772.1
# row number 22     3-8 yrs      Growth     Mumbai  15to25           2987.1
# row number 33     2-6 yrs   Analytics  Bengaluru   6to10            297.0
# row number 44     6-8 yrs   Analytics  Delhi NCR  25to50           2398.5
# row number 55     2-5 yrs  Consultant  Bengaluru    3to6            282.6
# row number 66    5-10 yrs   Analytics    Chennai  10to15           3043.8
# row number 77    8-13 yrs    Industry    Chennai  15to25           2629.8
# row number 88    5-10 yrs        Data  Bengaluru  15to25           2526.3
# row number 99    6-11 yrs        Data     Mumbai   6to10           1058.4
# row number 110    0-3 yrs    Business  Bengaluru    3to6             96.3
# row number 121   5-10 yrs   Analytics  Delhi NCR  15to25           1790.1
# ...

# %%
dataset.drop('new1',axis=1,inplace=True)
dataset
# Out:
#                experience   job_desig   location  salary  placement_count  \
# rows
# row number 0      2-4 yrs   Analytics     Mumbai   6to10           4031.1
# row number 11    5-10 yrs   Analytics  Delhi NCR   6to10           1772.1
# row number 22     3-8 yrs      Growth     Mumbai  15to25           2987.1
# row number 33     2-6 yrs   Analytics  Bengaluru   6to10            297.0
# row number 44     6-8 yrs   Analytics  Delhi NCR  25to50           2398.5
# row number 55     2-5 yrs  Consultant  Bengaluru    3to6            282.6
# row number 66    5-10 yrs   Analytics    Chennai  10to15           3043.8
# row number 77    8-13 yrs    Industry    Chennai  15to25           2629.8
# row number 88    5-10 yrs        Data  Bengaluru  15to25           2526.3
# row number 99    6-11 yrs        Data     Mumbai   6to10           1058.4
# row number 110    0-3 yrs    Business  Bengaluru    3to6             96.3
# row number 121   5-10 yrs   Analytics  Delhi NCR  15to25           1790.1
# ...

# %%
dataset['new1'] = dataset[['job_desig','location']].apply(lambda b : b[0][:3] + '-' + b[1][:3],axis=1)
dataset
# Out:
#                experience   job_desig   location  salary  placement_count  \
# rows
# row number 0      2-4 yrs   Analytics     Mumbai   6to10           4031.1
# row number 11    5-10 yrs   Analytics  Delhi NCR   6to10           1772.1
# row number 22     3-8 yrs      Growth     Mumbai  15to25           2987.1
# row number 33     2-6 yrs   Analytics  Bengaluru   6to10            297.0
# row number 44     6-8 yrs   Analytics  Delhi NCR  25to50           2398.5
# row number 55     2-5 yrs  Consultant  Bengaluru    3to6            282.6
# row number 66    5-10 yrs   Analytics    Chennai  10to15           3043.8
# row number 77    8-13 yrs    Industry    Chennai  15to25           2629.8
# row number 88    5-10 yrs        Data  Bengaluru  15to25           2526.3
# row number 99    6-11 yrs        Data     Mumbai   6to10           1058.4
# row number 110    0-3 yrs    Business  Bengaluru    3to6             96.3
# row number 121   5-10 yrs   Analytics  Delhi NCR  15to25           1790.1
# ...

# %%
dataset.drop('new1',axis=1,inplace=True)
dataset
# Out:
#                experience   job_desig   location  salary  placement_count  \
# rows
# row number 0      2-4 yrs   Analytics     Mumbai   6to10           4031.1
# row number 11    5-10 yrs   Analytics  Delhi NCR   6to10           1772.1
# row number 22     3-8 yrs      Growth     Mumbai  15to25           2987.1
# row number 33     2-6 yrs   Analytics  Bengaluru   6to10            297.0
# row number 44     6-8 yrs   Analytics  Delhi NCR  25to50           2398.5
# row number 55     2-5 yrs  Consultant  Bengaluru    3to6            282.6
# row number 66    5-10 yrs   Analytics    Chennai  10to15           3043.8
# row number 77    8-13 yrs    Industry    Chennai  15to25           2629.8
# row number 88    5-10 yrs        Data  Bengaluru  15to25           2526.3
# row number 99    6-11 yrs        Data     Mumbai   6to10           1058.4
# row number 110    0-3 yrs    Business  Bengaluru    3to6             96.3
# row number 121   5-10 yrs   Analytics  Delhi NCR  15to25           1790.1
# ...

# %%
print(dataset.iloc[3:8,2:4])
print()
print(dataset.loc[['row number 33','row number 44','row number 55','row number 66','row number 77'],['location','salary']])
# Out:
#                 location  salary
# rows
# row number 33  Bengaluru   6to10
# row number 44  Delhi NCR  25to50
# row number 55  Bengaluru    3to6
# row number 66    Chennai  10to15
# row number 77    Chennai  15to25
#
#                 location  salary
# rows
# row number 33  Bengaluru   6to10
# row number 44  Delhi NCR  25to50
# row number 55  Bengaluru    3to6
# row number 66    Chennai  10to15
# row number 77    Chennai  15to25

# %%
print((dataset.iloc[1,3:]).values)
print()
print(dataset.loc[['row number 11'],['salary','placement_count','rand','remarks','Upper','new']].values)
# Out:
# ['6to10' 1772.1 6 'Bad' 'DELHI NCR' 'Ana-Del']
#
# [['6to10' 1772.1 6 'Bad' 'DELHI NCR' 'Ana-Del']]

# %%
dataset
# Out:
#                experience   job_desig   location  salary  placement_count  \
# rows
# row number 0      2-4 yrs   Analytics     Mumbai   6to10           4031.1
# row number 11    5-10 yrs   Analytics  Delhi NCR   6to10           1772.1
# row number 22     3-8 yrs      Growth     Mumbai  15to25           2987.1
# row number 33     2-6 yrs   Analytics  Bengaluru   6to10            297.0
# row number 44     6-8 yrs   Analytics  Delhi NCR  25to50           2398.5
# row number 55     2-5 yrs  Consultant  Bengaluru    3to6            282.6
# row number 66    5-10 yrs   Analytics    Chennai  10to15           3043.8
# row number 77    8-13 yrs    Industry    Chennai  15to25           2629.8
# row number 88    5-10 yrs        Data  Bengaluru  15to25           2526.3
# row number 99    6-11 yrs        Data     Mumbai   6to10           1058.4
# row number 110    0-3 yrs    Business  Bengaluru    3to6             96.3
# row number 121   5-10 yrs   Analytics  Delhi NCR  15to25           1790.1
# ...

# %%
print(dataset.iloc[[2,5],[1,8]])
# Out:
#                 job_desig      new
# rows
# row number 22      Growth  Gro-Mum
# row number 55  Consultant  Con-Ben

# %%
print(dataset.loc[['row number 22','row number 55'],['job_desig','new']])
# Out:
#                 job_desig      new
# rows
# row number 22      Growth  Gro-Mum
# row number 55  Consultant  Con-Ben

# %%
print(dataset.iloc[0:dataset.shape[0],[0,2]])
# Out:
#                experience   location
# rows
# row number 0      2-4 yrs     Mumbai
# row number 11    5-10 yrs  Delhi NCR
# row number 22     3-8 yrs     Mumbai
# row number 33     2-6 yrs  Bengaluru
# row number 44     6-8 yrs  Delhi NCR
# row number 55     2-5 yrs  Bengaluru
# row number 66    5-10 yrs    Chennai
# row number 77    8-13 yrs    Chennai
# row number 88    5-10 yrs  Bengaluru
# row number 99    6-11 yrs     Mumbai
# row number 110    0-3 yrs  Bengaluru
# row number 121   5-10 yrs  Delhi NCR
# row number 132    3-6 yrs  Bengaluru

# %%
print(dataset.loc[['row number 0','row number 11','row number 22','row number 33','row number 44','row number 55','row number 66','row number 77','row number 88','row number 99','row number 110','row number 121','row number 132'],['experience','location']])

print()

print(dataset.loc[ : ,['experience','location']])
# Out:
#                experience   location
# rows
# row number 0      2-4 yrs     Mumbai
# row number 11    5-10 yrs  Delhi NCR
# row number 22     3-8 yrs     Mumbai
# row number 33     2-6 yrs  Bengaluru
# row number 44     6-8 yrs  Delhi NCR
# row number 55     2-5 yrs  Bengaluru
# row number 66    5-10 yrs    Chennai
# row number 77    8-13 yrs    Chennai
# row number 88    5-10 yrs  Bengaluru
# row number 99    6-11 yrs     Mumbai
# row number 110    0-3 yrs  Bengaluru
# row number 121   5-10 yrs  Delhi NCR
# row number 132    3-6 yrs  Bengaluru
#
#                experience   location
# rows
# row number 0      2-4 yrs     Mumbai
# row number 11    5-10 yrs  Delhi NCR
# row number 22     3-8 yrs     Mumbai
# row number 33     2-6 yrs  Bengaluru
# row number 44     6-8 yrs  Delhi NCR
# row number 55     2-5 yrs  Bengaluru
# row number 66    5-10 yrs    Chennai
# row number 77    8-13 yrs    Chennai
# row number 88    5-10 yrs  Bengaluru
# row number 99    6-11 yrs     Mumbai
# ...

# %%
print(dataset.iloc[[1,7,11], : ])
# Out:
#                experience  job_desig   location  salary  placement_count  \
# rows
# row number 11    5-10 yrs  Analytics  Delhi NCR   6to10           1772.1
# row number 77    8-13 yrs   Industry    Chennai  15to25           2629.8
# row number 121   5-10 yrs  Analytics  Delhi NCR  15to25           1790.1
#
#                 rand remarks      Upper      new
# rows
# row number 11      6     Bad  DELHI NCR  Ana-Del
# row number 77      4    Good    CHENNAI  Ind-Che
# row number 121     2     Bad  DELHI NCR  Ana-Del

# %%
import pandas as pd

dataset = pd.read_excel("student_placement.xlsx", sheet_name="value_data")
dataset
# Out:
#    experience   job_desig   location  salary  placement_count
# 0     2-4 yrs   Analytics     Mumbai   6to10             4479
# 1    5-10 yrs   Analytics  Delhi NCR   6to10             1969
# 2     3-8 yrs      Growth     Mumbai  15to25             3319
# 3     2-6 yrs   Analytics  Bengaluru   6to10              330
# 4     6-8 yrs   Analytics  Delhi NCR  25to50             2665
# 5     2-5 yrs  Consultant  Bengaluru    3to6              314
# 6    5-10 yrs   Analytics    Chennai  10to15             3382
# 7    8-13 yrs    Industry    Chennai  15to25             2922
# 8    5-10 yrs        Data  Bengaluru  15to25             2807
# 9    6-11 yrs        Data     Mumbai   6to10             1176
# 10    0-3 yrs    Business  Bengaluru    3to6              107
# 11   5-10 yrs   Analytics  Delhi NCR  15to25             1989
# 12    3-6 yrs   Analytics  Bengaluru    3to6              190

# %%
print(dataset.iloc[:,[0,2]])
# Out:
#    experience   location
# 0     2-4 yrs     Mumbai
# 1    5-10 yrs  Delhi NCR
# 2     3-8 yrs     Mumbai
# 3     2-6 yrs  Bengaluru
# 4     6-8 yrs  Delhi NCR
# 5     2-5 yrs  Bengaluru
# 6    5-10 yrs    Chennai
# 7    8-13 yrs    Chennai
# 8    5-10 yrs  Bengaluru
# 9    6-11 yrs     Mumbai
# 10    0-3 yrs  Bengaluru
# 11   5-10 yrs  Delhi NCR
# 12    3-6 yrs  Bengaluru

# %%
print(dataset.loc[:,['experience','location']])
# Out:
#    experience   location
# 0     2-4 yrs     Mumbai
# 1    5-10 yrs  Delhi NCR
# 2     3-8 yrs     Mumbai
# 3     2-6 yrs  Bengaluru
# 4     6-8 yrs  Delhi NCR
# 5     2-5 yrs  Bengaluru
# 6    5-10 yrs    Chennai
# 7    8-13 yrs    Chennai
# 8    5-10 yrs  Bengaluru
# 9    6-11 yrs     Mumbai
# 10    0-3 yrs  Bengaluru
# 11   5-10 yrs  Delhi NCR
# 12    3-6 yrs  Bengaluru

# %%
#25812

# %%
print(dataset.iloc[[2,5,8,12],[0,2,4]])
# Out:
#    experience   location  placement_count
# 2     3-8 yrs     Mumbai             3319
# 5     2-5 yrs  Bengaluru              314
# 8    5-10 yrs  Bengaluru             2807
# 12    3-6 yrs  Bengaluru              190

# %%
print(dataset.loc[[2,5,8,12],['experience','location','placement_count']])
# Out:
#    experience   location  placement_count
# 2     3-8 yrs     Mumbai             3319
# 5     2-5 yrs  Bengaluru              314
# 8    5-10 yrs  Bengaluru             2807
# 12    3-6 yrs  Bengaluru              190

# %%
#dataset.values

# %%
dataset
# Out:
#    experience   job_desig   location  salary  placement_count
# 0     2-4 yrs   Analytics     Mumbai   6to10             4479
# 1    5-10 yrs   Analytics  Delhi NCR   6to10             1969
# 2     3-8 yrs      Growth     Mumbai  15to25             3319
# 3     2-6 yrs   Analytics  Bengaluru   6to10              330
# 4     6-8 yrs   Analytics  Delhi NCR  25to50             2665
# 5     2-5 yrs  Consultant  Bengaluru    3to6              314
# 6    5-10 yrs   Analytics    Chennai  10to15             3382
# 7    8-13 yrs    Industry    Chennai  15to25             2922
# 8    5-10 yrs        Data  Bengaluru  15to25             2807
# 9    6-11 yrs        Data     Mumbai   6to10             1176
# 10    0-3 yrs    Business  Bengaluru    3to6              107
# 11   5-10 yrs   Analytics  Delhi NCR  15to25             1989
# 12    3-6 yrs   Analytics  Bengaluru    3to6              190

# %%
dataset['specialiation'] = dataset['job_desig'].apply(lambda s : 'Considered' if s == 'Data' else 'Not Considered')
dataset
# Out:
#    experience   job_desig   location  salary  placement_count   specialiation
# 0     2-4 yrs   Analytics     Mumbai   6to10             4479  Not Considered
# 1    5-10 yrs   Analytics  Delhi NCR   6to10             1969  Not Considered
# 2     3-8 yrs      Growth     Mumbai  15to25             3319  Not Considered
# 3     2-6 yrs   Analytics  Bengaluru   6to10              330  Not Considered
# 4     6-8 yrs   Analytics  Delhi NCR  25to50             2665  Not Considered
# 5     2-5 yrs  Consultant  Bengaluru    3to6              314  Not Considered
# 6    5-10 yrs   Analytics    Chennai  10to15             3382  Not Considered
# 7    8-13 yrs    Industry    Chennai  15to25             2922  Not Considered
# 8    5-10 yrs        Data  Bengaluru  15to25             2807      Considered
# 9    6-11 yrs        Data     Mumbai   6to10             1176      Considered
# 10    0-3 yrs    Business  Bengaluru    3to6              107  Not Considered
# ...

# %%
dataset['lopla'] = dataset[['location','placement_count']].apply(lambda a : str(a[0]).upper()[0:3] + '-->' + str(a[1]),axis=1)
dataset
# Out:
#    experience   job_desig   location  salary  placement_count   specialiation  \
# 0     2-4 yrs   Analytics     Mumbai   6to10             4479  Not Considered
# 1    5-10 yrs   Analytics  Delhi NCR   6to10             1969  Not Considered
# 2     3-8 yrs      Growth     Mumbai  15to25             3319  Not Considered
# 3     2-6 yrs   Analytics  Bengaluru   6to10              330  Not Considered
# 4     6-8 yrs   Analytics  Delhi NCR  25to50             2665  Not Considered
# 5     2-5 yrs  Consultant  Bengaluru    3to6              314  Not Considered
# 6    5-10 yrs   Analytics    Chennai  10to15             3382  Not Considered
# 7    8-13 yrs    Industry    Chennai  15to25             2922  Not Considered
# 8    5-10 yrs        Data  Bengaluru  15to25             2807      Considered
# 9    6-11 yrs        Data     Mumbai   6to10             1176      Considered
# 10    0-3 yrs    Business  Bengaluru    3to6              107  Not Considered
# ...

# %%
dataset
# Out:
#    experience   job_desig   location  salary  placement_count   specialiation  \
# 0     2-4 yrs   Analytics     Mumbai   6to10             4479  Not Considered
# 1    5-10 yrs   Analytics  Delhi NCR   6to10             1969  Not Considered
# 2     3-8 yrs      Growth     Mumbai  15to25             3319  Not Considered
# 3     2-6 yrs   Analytics  Bengaluru   6to10              330  Not Considered
# 4     6-8 yrs   Analytics  Delhi NCR  25to50             2665  Not Considered
# 5     2-5 yrs  Consultant  Bengaluru    3to6              314  Not Considered
# 6    5-10 yrs   Analytics    Chennai  10to15             3382  Not Considered
# 7    8-13 yrs    Industry    Chennai  15to25             2922  Not Considered
# 8    5-10 yrs        Data  Bengaluru  15to25             2807      Considered
# 9    6-11 yrs        Data     Mumbai   6to10             1176      Considered
# 10    0-3 yrs    Business  Bengaluru    3to6              107  Not Considered
# ...

# %%
dataset.drop(['specialiation','lopla'],axis=1,inplace=True)
dataset
# Out:
#    experience   job_desig   location  salary  placement_count
# 0     2-4 yrs   Analytics     Mumbai   6to10             4479
# 1    5-10 yrs   Analytics  Delhi NCR   6to10             1969
# 2     3-8 yrs      Growth     Mumbai  15to25             3319
# 3     2-6 yrs   Analytics  Bengaluru   6to10              330
# 4     6-8 yrs   Analytics  Delhi NCR  25to50             2665
# 5     2-5 yrs  Consultant  Bengaluru    3to6              314
# 6    5-10 yrs   Analytics    Chennai  10to15             3382
# 7    8-13 yrs    Industry    Chennai  15to25             2922
# 8    5-10 yrs        Data  Bengaluru  15to25             2807
# 9    6-11 yrs        Data     Mumbai   6to10             1176
# 10    0-3 yrs    Business  Bengaluru    3to6              107
# 11   5-10 yrs   Analytics  Delhi NCR  15to25             1989
# 12    3-6 yrs   Analytics  Bengaluru    3to6              190

# %%
dataset['alias'] = dataset['location'].apply(lambda l : str(l) + f'({str(l).upper()[0:3]})')
dataset
# Out:
#    experience   job_desig   location  salary  placement_count           alias
# 0     2-4 yrs   Analytics     Mumbai   6to10             4479     Mumbai(MUM)
# 1    5-10 yrs   Analytics  Delhi NCR   6to10             1969  Delhi NCR(DEL)
# 2     3-8 yrs      Growth     Mumbai  15to25             3319     Mumbai(MUM)
# 3     2-6 yrs   Analytics  Bengaluru   6to10              330  Bengaluru(BEN)
# 4     6-8 yrs   Analytics  Delhi NCR  25to50             2665  Delhi NCR(DEL)
# 5     2-5 yrs  Consultant  Bengaluru    3to6              314  Bengaluru(BEN)
# 6    5-10 yrs   Analytics    Chennai  10to15             3382    Chennai(CHE)
# 7    8-13 yrs    Industry    Chennai  15to25             2922    Chennai(CHE)
# 8    5-10 yrs        Data  Bengaluru  15to25             2807  Bengaluru(BEN)
# 9    6-11 yrs        Data     Mumbai   6to10             1176     Mumbai(MUM)
# 10    0-3 yrs    Business  Bengaluru    3to6              107  Bengaluru(BEN)
# ...

# %%
dataset['updated_placement_count'] = dataset['placement_count'] - dataset['placement_count']/10
dataset
# Out:
#    experience   job_desig   location  salary  placement_count           alias  \
# 0     2-4 yrs   Analytics     Mumbai   6to10             4479     Mumbai(MUM)
# 1    5-10 yrs   Analytics  Delhi NCR   6to10             1969  Delhi NCR(DEL)
# 2     3-8 yrs      Growth     Mumbai  15to25             3319     Mumbai(MUM)
# 3     2-6 yrs   Analytics  Bengaluru   6to10              330  Bengaluru(BEN)
# 4     6-8 yrs   Analytics  Delhi NCR  25to50             2665  Delhi NCR(DEL)
# 5     2-5 yrs  Consultant  Bengaluru    3to6              314  Bengaluru(BEN)
# 6    5-10 yrs   Analytics    Chennai  10to15             3382    Chennai(CHE)
# 7    8-13 yrs    Industry    Chennai  15to25             2922    Chennai(CHE)
# 8    5-10 yrs        Data  Bengaluru  15to25             2807  Bengaluru(BEN)
# 9    6-11 yrs        Data     Mumbai   6to10             1176     Mumbai(MUM)
# 10    0-3 yrs    Business  Bengaluru    3to6              107  Bengaluru(BEN)
# ...

# %%
dataset['final'] = dataset[['job_desig','alias']].apply(lambda x : str(x[0]).upper()[0:3] + '_' + str(x[1][-2:-5:-1]),axis=1)
dataset
# Out:
#    experience   job_desig   location  salary  placement_count           alias  \
# 0     2-4 yrs   Analytics     Mumbai   6to10             4479     Mumbai(MUM)
# 1    5-10 yrs   Analytics  Delhi NCR   6to10             1969  Delhi NCR(DEL)
# 2     3-8 yrs      Growth     Mumbai  15to25             3319     Mumbai(MUM)
# 3     2-6 yrs   Analytics  Bengaluru   6to10              330  Bengaluru(BEN)
# 4     6-8 yrs   Analytics  Delhi NCR  25to50             2665  Delhi NCR(DEL)
# 5     2-5 yrs  Consultant  Bengaluru    3to6              314  Bengaluru(BEN)
# 6    5-10 yrs   Analytics    Chennai  10to15             3382    Chennai(CHE)
# 7    8-13 yrs    Industry    Chennai  15to25             2922    Chennai(CHE)
# 8    5-10 yrs        Data  Bengaluru  15to25             2807  Bengaluru(BEN)
# 9    6-11 yrs        Data     Mumbai   6to10             1176     Mumbai(MUM)
# 10    0-3 yrs    Business  Bengaluru    3to6              107  Bengaluru(BEN)
# ...

# %%
dataset.drop(['alias','updated_placement_count','final'],axis=1,inplace=True)
dataset
# Out:
#    experience   job_desig   location  salary  placement_count
# 0     2-4 yrs   Analytics     Mumbai   6to10             4479
# 1    5-10 yrs   Analytics  Delhi NCR   6to10             1969
# 2     3-8 yrs      Growth     Mumbai  15to25             3319
# 3     2-6 yrs   Analytics  Bengaluru   6to10              330
# 4     6-8 yrs   Analytics  Delhi NCR  25to50             2665
# 5     2-5 yrs  Consultant  Bengaluru    3to6              314
# 6    5-10 yrs   Analytics    Chennai  10to15             3382
# 7    8-13 yrs    Industry    Chennai  15to25             2922
# 8    5-10 yrs        Data  Bengaluru  15to25             2807
# 9    6-11 yrs        Data     Mumbai   6to10             1176
# 10    0-3 yrs    Business  Bengaluru    3to6              107
# 11   5-10 yrs   Analytics  Delhi NCR  15to25             1989
# 12    3-6 yrs   Analytics  Bengaluru    3to6              190

# %%
dataset['alpha'] = [chr(x).upper() for x in range(97,dataset.shape[0]+97)]
dataset
# Out:
#    experience   job_desig   location  salary  placement_count alpha
# 0     2-4 yrs   Analytics     Mumbai   6to10             4479     A
# 1    5-10 yrs   Analytics  Delhi NCR   6to10             1969     B
# 2     3-8 yrs      Growth     Mumbai  15to25             3319     C
# 3     2-6 yrs   Analytics  Bengaluru   6to10              330     D
# 4     6-8 yrs   Analytics  Delhi NCR  25to50             2665     E
# 5     2-5 yrs  Consultant  Bengaluru    3to6              314     F
# 6    5-10 yrs   Analytics    Chennai  10to15             3382     G
# 7    8-13 yrs    Industry    Chennai  15to25             2922     H
# 8    5-10 yrs        Data  Bengaluru  15to25             2807     I
# 9    6-11 yrs        Data     Mumbai   6to10             1176     J
# 10    0-3 yrs    Business  Bengaluru    3to6              107     K
# 11   5-10 yrs   Analytics  Delhi NCR  15to25             1989     L
# 12    3-6 yrs   Analytics  Bengaluru    3to6              190     M

# %%
dataset.set_index('alpha')
# Out:
#       experience   job_desig   location  salary  placement_count
# alpha
# A        2-4 yrs   Analytics     Mumbai   6to10             4479
# B       5-10 yrs   Analytics  Delhi NCR   6to10             1969
# C        3-8 yrs      Growth     Mumbai  15to25             3319
# D        2-6 yrs   Analytics  Bengaluru   6to10              330
# E        6-8 yrs   Analytics  Delhi NCR  25to50             2665
# F        2-5 yrs  Consultant  Bengaluru    3to6              314
# G       5-10 yrs   Analytics    Chennai  10to15             3382
# H       8-13 yrs    Industry    Chennai  15to25             2922
# I       5-10 yrs        Data  Bengaluru  15to25             2807
# J       6-11 yrs        Data     Mumbai   6to10             1176
# K        0-3 yrs    Business  Bengaluru    3to6              107
# L       5-10 yrs   Analytics  Delhi NCR  15to25             1989
# M        3-6 yrs   Analytics  Bengaluru    3to6              190

# %%
dataset
# Out:
#    experience   job_desig   location  salary  placement_count alpha
# 0     2-4 yrs   Analytics     Mumbai   6to10             4479     A
# 1    5-10 yrs   Analytics  Delhi NCR   6to10             1969     B
# 2     3-8 yrs      Growth     Mumbai  15to25             3319     C
# 3     2-6 yrs   Analytics  Bengaluru   6to10              330     D
# 4     6-8 yrs   Analytics  Delhi NCR  25to50             2665     E
# 5     2-5 yrs  Consultant  Bengaluru    3to6              314     F
# 6    5-10 yrs   Analytics    Chennai  10to15             3382     G
# 7    8-13 yrs    Industry    Chennai  15to25             2922     H
# 8    5-10 yrs        Data  Bengaluru  15to25             2807     I
# 9    6-11 yrs        Data     Mumbai   6to10             1176     J
# 10    0-3 yrs    Business  Bengaluru    3to6              107     K
# 11   5-10 yrs   Analytics  Delhi NCR  15to25             1989     L
# 12    3-6 yrs   Analytics  Bengaluru    3to6              190     M

# %%
dataset.reset_index()
# Out:
#    alpha experience   job_desig   location  salary  placement_count
# 0      A    2-4 yrs   Analytics     Mumbai   6to10             4479
# 1      B   5-10 yrs   Analytics  Delhi NCR   6to10             1969
# 2      C    3-8 yrs      Growth     Mumbai  15to25             3319
# 3      D    2-6 yrs   Analytics  Bengaluru   6to10              330
# 4      E    6-8 yrs   Analytics  Delhi NCR  25to50             2665
# 5      F    2-5 yrs  Consultant  Bengaluru    3to6              314
# 6      G   5-10 yrs   Analytics    Chennai  10to15             3382
# 7      H   8-13 yrs    Industry    Chennai  15to25             2922
# 8      I   5-10 yrs        Data  Bengaluru  15to25             2807
# 9      J   6-11 yrs        Data     Mumbai   6to10             1176
# 10     K    0-3 yrs    Business  Bengaluru    3to6              107
# 11     L   5-10 yrs   Analytics  Delhi NCR  15to25             1989
# 12     M    3-6 yrs   Analytics  Bengaluru    3to6              190

# %%
dataset.reset_index(inplace=True)

# %%
dataset.drop('alpha',axis=1,inplace=True)

# %%
dataset
# Out:
#    experience   job_desig   location  salary  placement_count
# 0     2-4 yrs   Analytics     Mumbai   6to10             4479
# 1    5-10 yrs   Analytics  Delhi NCR   6to10             1969
# 2     3-8 yrs      Growth     Mumbai  15to25             3319
# 3     2-6 yrs   Analytics  Bengaluru   6to10              330
# 4     6-8 yrs   Analytics  Delhi NCR  25to50             2665
# 5     2-5 yrs  Consultant  Bengaluru    3to6              314
# 6    5-10 yrs   Analytics    Chennai  10to15             3382
# 7    8-13 yrs    Industry    Chennai  15to25             2922
# 8    5-10 yrs        Data  Bengaluru  15to25             2807
# 9    6-11 yrs        Data     Mumbai   6to10             1176
# 10    0-3 yrs    Business  Bengaluru    3to6              107
# 11   5-10 yrs   Analytics  Delhi NCR  15to25             1989
# 12    3-6 yrs   Analytics  Bengaluru    3to6              190

# %%
df = pd.read_excel('student_placement.xlsx')
df.head()
# Out:
#   experience job_desig   location  salary  placement_count
# 0    1-6 yrs      Data  Ahmedabad    0to3             3914
# 1    1-5 yrs      Data  Ahmedabad    3to6             3365
# 2   7-11 yrs      Data  Ahmedabad  10to15             1301
# 3    0-3 yrs       SEO  Ahmedabad    3to6             1248
# 4    1-4 yrs    Social  Ahmedabad    0to3             2682

# %%
df.shape
# Out:
# (105, 5)

# %%
res = df[df['placement_count']>4000]
print(res.head())
res.shape
print(res)
# Out:
#    experience  job_desig   location  salary  placement_count
# 9    8-10 yrs  Analytics  Bengaluru  10to15             4541
# 56   8-12 yrs  Analytics  Delhi NCR  25to50             4470
# 58    3-8 yrs  Analytics  Delhi NCR   6to10             4330
# 77    2-4 yrs  Analytics     Mumbai   6to10             4479
# 78    2-7 yrs  Analytics     Mumbai  15to25             4167
#     experience   job_desig   location  salary  placement_count
# 9     8-10 yrs   Analytics  Bengaluru  10to15             4541
# 56    8-12 yrs   Analytics  Delhi NCR  25to50             4470
# 58     3-8 yrs   Analytics  Delhi NCR   6to10             4330
# 77     2-4 yrs   Analytics     Mumbai   6to10             4479
# 78     2-7 yrs   Analytics     Mumbai  15to25             4167
# 82     4-8 yrs   Analytics     Mumbai   6to10             4840
# 90     4-9 yrs  Consultant     Mumbai  15to25             5018
# 94    5-10 yrs        Data     Mumbai    3to6             4568
# ...

# %%
res = df[df['placement_count']>4000]
print(res.index)

print(res[['location','experience']])
# Out:
# Index([9, 56, 58, 77, 78, 82, 90, 94, 96, 103, 104], dtype='int64')
#       location experience
# 9    Bengaluru   8-10 yrs
# 56   Delhi NCR   8-12 yrs
# 58   Delhi NCR    3-8 yrs
# 77      Mumbai    2-4 yrs
# 78      Mumbai    2-7 yrs
# 82      Mumbai    4-8 yrs
# 90      Mumbai    4-9 yrs
# 94      Mumbai   5-10 yrs
# 96      Mumbai    3-5 yrs
# 103     Mumbai    1-5 yrs
# 104     Mumbai    2-5 yrs

# %%
res = df[df['placement_count']>4000][['location','experience']].head(4)
res
# Out:
#      location experience
# 9   Bengaluru   8-10 yrs
# 56  Delhi NCR   8-12 yrs
# 58  Delhi NCR    3-8 yrs
# 77     Mumbai    2-4 yrs

# %%
res = df[df['location'] == 'Mumbai']
res
# Out:
#     experience   job_desig location  salary  placement_count
# 77     2-4 yrs   Analytics   Mumbai   6to10             4479
# 78     2-7 yrs   Analytics   Mumbai  15to25             4167
# 79     2-5 yrs   Analytics   Mumbai  10to15             3848
# 80     0-0 yrs   Analytics   Mumbai    0to3             1167
# 81     2-7 yrs   Analytics   Mumbai  10to15             3838
# 82     4-8 yrs   Analytics   Mumbai   6to10             4840
# 83   15-25 yrs   Analytics   Mumbai  25to50              322
# 84     4-8 yrs   Analytics   Mumbai    3to6             3767
# 85     4-9 yrs   Analytics   Mumbai  10to15             1863
# 86     4-8 yrs   Analytics   Mumbai    3to6             3767
# 87     3-8 yrs    Business   Mumbai  15to25             2809
# 88     4-9 yrs    Business   Mumbai   6to10             2434
# 89     2-4 yrs  Consultant   Mumbai  15to25             3383
# 90     4-9 yrs  Consultant   Mumbai  15to25             5018
# ...

# %%
df['location'] == 'Mumbai'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 100     True
# 101     True
# 102     True
# 103     True
# 104     True
# Name: location, Length: 105, dtype: bool

# %%
res = df[(df['location'] == 'Mumbai') & (df['placement_count']>4000)]
res
# Out:
#     experience   job_desig location  salary  placement_count
# 77     2-4 yrs   Analytics   Mumbai   6to10             4479
# 78     2-7 yrs   Analytics   Mumbai  15to25             4167
# 82     4-8 yrs   Analytics   Mumbai   6to10             4840
# 90     4-9 yrs  Consultant   Mumbai  15to25             5018
# 94    5-10 yrs        Data   Mumbai    3to6             4568
# 96     3-5 yrs        Data   Mumbai  10to15             4904
# 103    1-5 yrs      Senior   Mumbai   6to10             4448
# 104    2-5 yrs      Senior   Mumbai    3to6             4011

# %%
print(df.head())
print()
print(df.shape)
print()
res = df.sort_values(by=['location'])
print(res.head())
print()
print(res.shape)
# Out:
#   experience job_desig   location  salary  placement_count
# 0    1-6 yrs      Data  Ahmedabad    0to3             3914
# 1    1-5 yrs      Data  Ahmedabad    3to6             3365
# 2   7-11 yrs      Data  Ahmedabad  10to15             1301
# 3    0-3 yrs       SEO  Ahmedabad    3to6             1248
# 4    1-4 yrs    Social  Ahmedabad    0to3             2682
#
# (105, 5)
#
#   experience job_desig   location  salary  placement_count
# 0    1-6 yrs      Data  Ahmedabad    0to3             3914
# 1    1-5 yrs      Data  Ahmedabad    3to6             3365
# 2   7-11 yrs      Data  Ahmedabad  10to15             1301
# 3    0-3 yrs       SEO  Ahmedabad    3to6             1248
# 4    1-4 yrs    Social  Ahmedabad    0to3             2682
#
# (105, 5)

# %%
#df
#df.tail()
print(df.sort_values(by=['placement_count'],ascending=False))
print(' NEXT IS '.center(40,'*'))
print(df.sort_values(by=['placement_count','location'],ascending=[True,False]))
print()
print(df.sort_values(by=['placement_count','location'],ascending=[True,False]).head())
print()
print(df.sort_values(by=['location','placement_count'],ascending=[True,False]))
print()
print(df.sort_values(by=['location','placement_count'],ascending=[True,False]).head())
# Out:
#     experience   job_desig   location  salary  placement_count
# 90     4-9 yrs  Consultant     Mumbai  15to25             5018
# 96     3-5 yrs        Data     Mumbai  10to15             4904
# 82     4-8 yrs   Analytics     Mumbai   6to10             4840
# 94    5-10 yrs        Data     Mumbai    3to6             4568
# 9     8-10 yrs   Analytics  Bengaluru  10to15             4541
# ..         ...         ...        ...     ...              ...
# 102    2-5 yrs     Program     Mumbai    3to6              190
# 8      1-5 yrs   Analytics  Bengaluru   6to10              190
# 52     1-5 yrs   Analytics  Delhi NCR   6to10              190
# 19     0-3 yrs    Business  Bengaluru    3to6              107
# 25     3-8 yrs        Data  Bengaluru  10to15               16
#
# [105 rows x 5 columns]
# *************** NEXT IS ****************
#     experience   job_desig   location  salary  placement_count
# 25     3-8 yrs        Data  Bengaluru  10to15               16
# ...
