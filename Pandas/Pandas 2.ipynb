# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("student_placement.xlsx")
df.head()
# Out:
#   experience  job_desig   location  salary  placement_count
# 0    2-4 yrs  Analytics     Mumbai   6to10             4479
# 1   5-10 yrs  Analytics  Delhi NCR   6to10             1969
# 2    3-8 yrs     Growth     Mumbai  15to25             3319
# 3    2-6 yrs  Analytics  Bengaluru   6to10              330
# 4    6-8 yrs  Analytics  Delhi NCR  25to50             2665

# %%
table_2 = pd.read_csv("data.txt", sep = "\t")
table_2.head()
# Out:
#    job_desig   location  salary
# 0  Analytics     Mumbai   6to10
# 1  Analytics  Delhi NCR   6to10
# 2     Growth     Mumbai  15to25
# 3  Analytics  Bengaluru   6to10
# 4  Analytics  Delhi NCR  25to50

# %%
table_1 = pd.read_csv("data.csv", sep = ",")
table_1.head()
# Out:
#   experience  job_desig   location  salary  placement_count
# 0    2-4 yrs  Analytics     Mumbai   6to10             4479
# 1   5-10 yrs  Analytics  Delhi NCR   6to10             1969
# 2    3-8 yrs     Growth     Mumbai  15to25             3319
# 3    2-6 yrs  Analytics  Bengaluru   6to10              330
# 4    6-8 yrs  Analytics  Delhi NCR  25to50             2665

# %%
newData = pd.concat([table_1, table_2], axis = 1)

newData.head()

# To save the data in tabular form
# dfName.to_TABULARFORMAT(fileName)

newData.to_excel("newData.xlsx", )
newData.to_csv("new_data.txt", sep = ";")

# %%
# to save data in different sheets of the excel file
# package -> excelWriter

# %% [markdown]
# **value**
#
# - this is anything that is present inside the tabular form or inside a single column or a single row

# %%
dataset = pd.read_excel("student_placement.xlsx", sheet_name="value_data")
dataset
# Out:
#    experience   job_desig   location  salary  placement_count
# 0     2-4 yrs   Analytics     Mumbai   6to10             4479
# 1    5-10 yrs   Analytics  Delhi NCR   6to10             1969
# 2     3-8 yrs      Growth     Mumbai  15to25             3319
# 3     2-6 yrs   Analytics  Bengaluru   6to10              330
# 4     6-8 yrs   Analytics  Delhi NCR  25to50             2665
# 5     2-5 yrs  Consultant  Bengaluru    3to6              314
# 6    5-10 yrs   Analytics    Chennai  10to15             3382
# 7    8-13 yrs    Industry    Chennai  15to25             2922
# 8    5-10 yrs        Data  Bengaluru  15to25             2807
# 9    6-11 yrs        Data     Mumbai   6to10             1176
# 10    0-3 yrs    Business  Bengaluru    3to6              107
# 11   5-10 yrs   Analytics  Delhi NCR  15to25             1989
# 12    3-6 yrs   Analytics  Bengaluru    3to6              190

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# tabular value
print( dataset.values )
# Out:
# [['2-4 yrs' 'Analytics' 'Mumbai' '6to10' 4479]
#  ['5-10 yrs' 'Analytics' 'Delhi NCR' '6to10' 1969]
#  ['3-8 yrs' 'Growth' 'Mumbai' '15to25' 3319]
#  ['2-6 yrs' 'Analytics' 'Bengaluru' '6to10' 330]
#  ['6-8 yrs' 'Analytics' 'Delhi NCR' '25to50' 2665]
#  ['2-5 yrs' 'Consultant' 'Bengaluru' '3to6' 314]
#  ['5-10 yrs' 'Analytics' 'Chennai' '10to15' 3382]
#  ['8-13 yrs' 'Industry' 'Chennai' '15to25' 2922]
#  ['5-10 yrs' 'Data' 'Bengaluru' '15to25' 2807]
#  ['6-11 yrs' 'Data' 'Mumbai' '6to10' 1176]
#  ['0-3 yrs' 'Business' 'Bengaluru' '3to6' 107]
#  ['5-10 yrs' 'Analytics' 'Delhi NCR' '15to25' 1989]
#  ['3-6 yrs' 'Analytics' 'Bengaluru' '3to6' 190]]

# %%
# single row value

row_4 = dataset.iloc[4, ]
print( row_4.values )
# Out:
# ['6-8 yrs' 'Analytics' 'Delhi NCR' '25to50' 2665]

# %%
# single column value

col_3 = dataset.iloc[ : , 3]
print( col_3.values )
# Out:
# ['6to10' '6to10' '15to25' '6to10' '25to50' '3to6' '10to15' '15to25'
#  '15to25' '6to10' '3to6' '15to25' '3to6']

# %%
df.describe(include = 'all')
# Out:
#        experience  job_desig   location  salary  placement_count
# count         105        105        105     105       105.000000
# unique         41         19          6       6              NaN
# top       2-5 yrs  Analytics  Bengaluru  15to25              NaN
# freq           11         54         33      24              NaN
# mean          NaN        NaN        NaN     NaN      2183.628571
# std           NaN        NaN        NaN     NaN      1374.740222
# min           NaN        NaN        NaN     NaN        16.000000
# 25%           NaN        NaN        NaN     NaN       921.000000
# 50%           NaN        NaN        NaN     NaN      1989.000000
# 75%           NaN        NaN        NaN     NaN      3319.000000
# max           NaN        NaN        NaN     NaN      5018.000000

# %%
# Numerical Column ???

print( df[['placement_count']].max() )
print()
print( df['placement_count'].max() )

print()
print( df['placement_count'].min() )
print( df['placement_count'].mean() )
print( df['placement_count'].median() )
print( df['placement_count'].sum() )
print( df['placement_count'].std() )
print( df['placement_count'].count() )
# Out:
# placement_count    5018
# dtype: int64
#
# 5018
#
# 16
# 2183.6285714285714
# 1989.0
# 229281
# 1374.740222013591
# 105

# %%
# String (categorical) Column ???

print()
# Unique -> display distinct names
print( df['location'].unique() )


print()
# nunique -> display total distinct names
print( df['location'].nunique() )

print()
# nunique -> display frequency/count distinct names
print( df['location'].value_counts() )
# Out:
# ['Mumbai' 'Delhi NCR' 'Bengaluru' 'Chennai' 'Ahmedabad' 'Kolkata']
#
# 6
#
# location
# Bengaluru    33
# Delhi NCR    29
# Mumbai       28
# Chennai       8
# Ahmedabad     5
# Kolkata       2
# Name: count, dtype: int64

# %% [markdown]
# **value counts**
#
# ![image.png](attachment:image.png)

# %%
# Copy the dataset to avoid aliasing
df_new = df.copy()
df_new.head(1)
# Out:
#   experience  job_desig location salary  placement_count
# 0    2-4 yrs  Analytics   Mumbai  6to10             4479

# %% [markdown]
# **duplicated**
#
# - display the records that are there more than 1 time

# %%
df[ df.duplicated() ] # query..
# Out:
#     experience  job_desig   location  salary  placement_count
# 68     2-5 yrs    Program     Mumbai    3to6              190
# 91    8-11 yrs  Analytics  Bengaluru  25to50             2884
# 99     3-8 yrs     Growth     Mumbai  15to25             3319
# 100    6-9 yrs       Data  Bengaluru  15to25             3076
# 101    4-8 yrs  Analytics     Mumbai    3to6             3767
# 102   8-13 yrs  Analytics  Delhi NCR  25to50             2574
# 103    1-6 yrs     Senior  Bengaluru  15to25             1217
# 104    1-3 yrs  Analytics    Chennai  10to15              860

# %% [markdown]
# **remove the duplicated**
#
# - dfName.drop_duplicates()

# %%
df_without_duplicates = df.drop_duplicates() # inplace
print( df_without_duplicates.shape )

df_without_duplicates.head()
# Out:
# (97, 5)
#   experience  job_desig   location  salary  placement_count
# 0    2-4 yrs  Analytics     Mumbai   6to10             4479
# 1   5-10 yrs  Analytics  Delhi NCR   6to10             1969
# 2    3-8 yrs     Growth     Mumbai  15to25             3319
# 3    2-6 yrs  Analytics  Bengaluru   6to10              330
# 4    6-8 yrs  Analytics  Delhi NCR  25to50             2665

# %%
df.drop_duplicates()
# Out:
#    experience  job_desig   location  salary  placement_count
# 0     2-4 yrs  Analytics     Mumbai   6to10             4479
# 1    5-10 yrs  Analytics  Delhi NCR   6to10             1969
# 2     3-8 yrs     Growth     Mumbai  15to25             3319
# 3     2-6 yrs  Analytics  Bengaluru   6to10              330
# 4     6-8 yrs  Analytics  Delhi NCR  25to50             2665
# ..        ...        ...        ...     ...              ...
# 94    4-8 yrs  Analytics    Kolkata  10to15              772
# 95    3-5 yrs       Data     Mumbai  10to15             4904
# 96   7-11 yrs       Data  Ahmedabad  10to15             1301
# 97  11-15 yrs   Business  Bengaluru  15to25              280
# 98    4-9 yrs  Analytics     Mumbai  10to15             1863
#
# [97 rows x 5 columns]

# %%
df
# Out:
#     experience  job_desig   location  salary  placement_count
# 0      2-4 yrs  Analytics     Mumbai   6to10             4479
# 1     5-10 yrs  Analytics  Delhi NCR   6to10             1969
# 2      3-8 yrs     Growth     Mumbai  15to25             3319
# 3      2-6 yrs  Analytics  Bengaluru   6to10              330
# 4      6-8 yrs  Analytics  Delhi NCR  25to50             2665
# ..         ...        ...        ...     ...              ...
# 100    6-9 yrs       Data  Bengaluru  15to25             3076
# 101    4-8 yrs  Analytics     Mumbai    3to6             3767
# 102   8-13 yrs  Analytics  Delhi NCR  25to50             2574
# 103    1-6 yrs     Senior  Bengaluru  15to25             1217
# 104    1-3 yrs  Analytics    Chennai  10to15              860
#
# [105 rows x 5 columns]

# %%
df1 = df.copy()
df1.drop_duplicates(inplace=True)
print( df1.shape )
df1.head()
# Out:
# (97, 5)
#   experience  job_desig   location  salary  placement_count
# 0    2-4 yrs  Analytics     Mumbai   6to10             4479
# 1   5-10 yrs  Analytics  Delhi NCR   6to10             1969
# 2    3-8 yrs     Growth     Mumbai  15to25             3319
# 3    2-6 yrs  Analytics  Bengaluru   6to10              330
# 4    6-8 yrs  Analytics  Delhi NCR  25to50             2665

# %% [markdown]
# **Indexing**
#
# - set an index and remove an index
#
# dfName.index : display the index values

# %% [markdown]
# **Set Indexing**
#
# A. set the index while reading the dataset
#  - index_col parameter inside the dataset read methods

# %%
myData = pd.read_excel("student_placement.xlsx", index_col=3, 
                       sheet_name="data")
myData.head()
# Out:
#        experience  job_desig   location  placement_count
# salary
# 6to10     2-4 yrs  Analytics     Mumbai             4479
# 6to10    5-10 yrs  Analytics  Delhi NCR             1969
# 15to25    3-8 yrs     Growth     Mumbai             3319
# 6to10     2-6 yrs  Analytics  Bengaluru              330
# 25to50    6-8 yrs  Analytics  Delhi NCR             2665

# %%
print( myData.index.values )
# Out:
# ['6to10' '6to10' '15to25' '6to10' '25to50' '3to6' '10to15' '15to25'
#  '15to25' '6to10' '3to6' '15to25' '3to6' '10to15' '15to25' '10to15' '3to6'
#  '6to10' '15to25' '15to25' '6to10' '3to6' '10to15' '10to15' '0to3' '3to6'
#  '25to50' '10to15' '6to10' '3to6' '10to15' '6to10' '15to25' '25to50'
#  '3to6' '3to6' '15to25' '15to25' '25to50' '6to10' '10to15' '0to3' '0to3'
#  '6to10' '3to6' '6to10' '10to15' '25to50' '25to50' '10to15' '3to6'
#  '10to15' '6to10' '25to50' '15to25' '3to6' '3to6' '15to25' '10to15' '3to6'
#  '25to50' '15to25' '15to25' '6to10' '15to25' '25to50' '6to10' '3to6'
#  '3to6' '10to15' '15to25' '6to10' '3to6' '3to6' '15to25' '25to50' '0to3'
#  '25to50' '3to6' '10to15' '25to50' '25to50' '6to10' '3to6' '25to50'
#  '15to25' '10to15' '10to15' '15to25' '10to15' '6to10' '25to50' '15to25'
#  '6to10' '10to15' '10to15' '10to15' '15to25' '10to15' '15to25' '15to25'
#  '3to6' '25to50' '15to25' '10to15']

# %%
myData = pd.read_excel("student_placement.xlsx", index_col="job_desig", 
                       sheet_name="data")
myData.head()
# Out:
#           experience   location  salary  placement_count
# job_desig
# Analytics    2-4 yrs     Mumbai   6to10             4479
# Analytics   5-10 yrs  Delhi NCR   6to10             1969
# Growth       3-8 yrs     Mumbai  15to25             3319
# Analytics    2-6 yrs  Bengaluru   6to10              330
# Analytics    6-8 yrs  Delhi NCR  25to50             2665

# %% [markdown]
# **Set Indexing**
#
# B. set the index at any time
#  - dfName.set_index("columnName", inplace = False)

# %%
myData = pd.read_excel("student_placement.xlsx", sheet_name="data")
myData.head()
# Out:
#   experience  job_desig   location  salary  placement_count
# 0    2-4 yrs  Analytics     Mumbai   6to10             4479
# 1   5-10 yrs  Analytics  Delhi NCR   6to10             1969
# 2    3-8 yrs     Growth     Mumbai  15to25             3319
# 3    2-6 yrs  Analytics  Bengaluru   6to10              330
# 4    6-8 yrs  Analytics  Delhi NCR  25to50             2665

# %%
myData.set_index("job_desig")

# to make the changes permanenet
# myData = myData.set_index("job_desig")

# to make the changes permanenet
myData.set_index("job_desig", inplace=True) 
# inplace means that changes are placed inside the dataset permanently.

# %%
myData.head()
# Out:
#           experience   location  salary  placement_count
# job_desig
# Analytics    2-4 yrs     Mumbai   6to10             4479
# Analytics   5-10 yrs  Delhi NCR   6to10             1969
# Growth       3-8 yrs     Mumbai  15to25             3319
# Analytics    2-6 yrs  Bengaluru   6to10              330
# Analytics    6-8 yrs  Delhi NCR  25to50             2665

# %% [markdown]
# **Remove Indexing**
#
# A. Remove the index from the dataset
#  - dfName.reset_index(inplace, drop)

# %%
myData = pd.read_excel("student_placement.xlsx", index_col = "location", 
                       sheet_name="data")
myData.head()
# Out:
#           experience  job_desig  salary  placement_count
# location
# Mumbai       2-4 yrs  Analytics   6to10             4479
# Delhi NCR   5-10 yrs  Analytics   6to10             1969
# Mumbai       3-8 yrs     Growth  15to25             3319
# Bengaluru    2-6 yrs  Analytics   6to10              330
# Delhi NCR    6-8 yrs  Analytics  25to50             2665

# %%
myData.reset_index(inplace=True)

# %%
myData.reset_index()
# Out:
#       location experience  job_desig  salary  placement_count
# 0       Mumbai    2-4 yrs  Analytics   6to10             4479
# 1    Delhi NCR   5-10 yrs  Analytics   6to10             1969
# 2       Mumbai    3-8 yrs     Growth  15to25             3319
# 3    Bengaluru    2-6 yrs  Analytics   6to10              330
# 4    Delhi NCR    6-8 yrs  Analytics  25to50             2665
# ..         ...        ...        ...     ...              ...
# 100  Bengaluru    6-9 yrs       Data  15to25             3076
# 101     Mumbai    4-8 yrs  Analytics    3to6             3767
# 102  Delhi NCR   8-13 yrs  Analytics  25to50             2574
# 103  Bengaluru    1-6 yrs     Senior  15to25             1217
# 104    Chennai    1-3 yrs  Analytics  10to15              860
#
# [105 rows x 5 columns]

# %%
myData.head()
# Out:
#     location experience  job_desig  salary  placement_count
# 0     Mumbai    2-4 yrs  Analytics   6to10             4479
# 1  Delhi NCR   5-10 yrs  Analytics   6to10             1969
# 2     Mumbai    3-8 yrs     Growth  15to25             3319
# 3  Bengaluru    2-6 yrs  Analytics   6to10              330
# 4  Delhi NCR    6-8 yrs  Analytics  25to50             2665

# %%
myData = pd.read_excel("student_placement.xlsx", index_col = "location", 
                       sheet_name="data")
myData.head()
# Out:
#           experience  job_desig  salary  placement_count
# location
# Mumbai       2-4 yrs  Analytics   6to10             4479
# Delhi NCR   5-10 yrs  Analytics   6to10             1969
# Mumbai       3-8 yrs     Growth  15to25             3319
# Bengaluru    2-6 yrs  Analytics   6to10              330
# Delhi NCR    6-8 yrs  Analytics  25to50             2665

# %%
myData.reset_index( inplace = True, drop = True ) # drop means delete

# %%
myData.head()
# Out:
#   experience  job_desig  salary  placement_count
# 0    2-4 yrs  Analytics   6to10             4479
# 1   5-10 yrs  Analytics   6to10             1969
# 2    3-8 yrs     Growth  15to25             3319
# 3    2-6 yrs  Analytics   6to10              330
# 4    6-8 yrs  Analytics  25to50             2665

# %% [markdown]
# **Create and Delete COlumns**
#
# A. Create a Column
#
# - if column name exists, then values are updated else  new column is      created
# - Size of the rows shall be same
# - dfName[columnName] = value

# %%
# dict ???

# %%
dataset = pd.read_excel("student_placement.xlsx", sheet_name="value_data")
dataset
# Out:
#    experience   job_desig   location  salary  placement_count
# 0     2-4 yrs   Analytics     Mumbai   6to10             4479
# 1    5-10 yrs   Analytics  Delhi NCR   6to10             1969
# 2     3-8 yrs      Growth     Mumbai  15to25             3319
# 3     2-6 yrs   Analytics  Bengaluru   6to10              330
# 4     6-8 yrs   Analytics  Delhi NCR  25to50             2665
# 5     2-5 yrs  Consultant  Bengaluru    3to6              314
# 6    5-10 yrs   Analytics    Chennai  10to15             3382
# 7    8-13 yrs    Industry    Chennai  15to25             2922
# 8    5-10 yrs        Data  Bengaluru  15to25             2807
# 9    6-11 yrs        Data     Mumbai   6to10             1176
# 10    0-3 yrs    Business  Bengaluru    3to6              107
# 11   5-10 yrs   Analytics  Delhi NCR  15to25             1989
# 12    3-6 yrs   Analytics  Bengaluru    3to6              190

# %%
import random
dataset['rand'] = [ random.randint(1 , 10) for i in range(dataset.shape[0]) ]

# %%
[ random.randint(1 , 10) for i in range(dataset.shape[0]) ]
# Out:
# [8, 7, 6, 9, 8, 10, 1, 4, 6, 5, 9, 8, 3]

# %%
import random
random.randint(1 , 10)
# Out:
# 2

# %%
dataset.shape[0]
# Out:
# 13

# %%
dataset.head()
# Out:
#   experience  job_desig   location  salary  placement_count  rand
# 0    2-4 yrs  Analytics     Mumbai   6to10             4479     8
# 1   5-10 yrs  Analytics  Delhi NCR   6to10             1969     7
# 2    3-8 yrs     Growth     Mumbai  15to25             3319     6
# 3    2-6 yrs  Analytics  Bengaluru   6to10              330    10
# 4    6-8 yrs  Analytics  Delhi NCR  25to50             2665    10

# %%
dataset['new placement count'] = dataset['placement_count'] - (dataset['placement_count']/10)

# %%
dataset
# Out:
#    experience   job_desig   location  salary  placement_count  rand  \
# 0     2-4 yrs   Analytics     Mumbai   6to10             4479     8
# 1    5-10 yrs   Analytics  Delhi NCR   6to10             1969     7
# 2     3-8 yrs      Growth     Mumbai  15to25             3319     6
# 3     2-6 yrs   Analytics  Bengaluru   6to10              330    10
# 4     6-8 yrs   Analytics  Delhi NCR  25to50             2665    10
# 5     2-5 yrs  Consultant  Bengaluru    3to6              314     1
# 6    5-10 yrs   Analytics    Chennai  10to15             3382     8
# 7    8-13 yrs    Industry    Chennai  15to25             2922     7
# 8    5-10 yrs        Data  Bengaluru  15to25             2807    10
# 9    6-11 yrs        Data     Mumbai   6to10             1176     7
# 10    0-3 yrs    Business  Bengaluru    3to6              107     1
# 11   5-10 yrs   Analytics  Delhi NCR  15to25             1989     2
# 12    3-6 yrs   Analytics  Bengaluru    3to6              190     3
#
# ...

# %%
dataset['rand'] = dataset['rand'] ** 2

# %%
# dictName[key] = value

# %%
dataset
# Out:
#    experience   job_desig   location  salary  placement_count  rand  \
# 0     2-4 yrs   Analytics     Mumbai   6to10             4479    64
# 1    5-10 yrs   Analytics  Delhi NCR   6to10             1969    49
# 2     3-8 yrs      Growth     Mumbai  15to25             3319    36
# 3     2-6 yrs   Analytics  Bengaluru   6to10              330   100
# 4     6-8 yrs   Analytics  Delhi NCR  25to50             2665   100
# 5     2-5 yrs  Consultant  Bengaluru    3to6              314     1
# 6    5-10 yrs   Analytics    Chennai  10to15             3382    64
# 7    8-13 yrs    Industry    Chennai  15to25             2922    49
# 8    5-10 yrs        Data  Bengaluru  15to25             2807   100
# 9    6-11 yrs        Data     Mumbai   6to10             1176    49
# 10    0-3 yrs    Business  Bengaluru    3to6              107     1
# 11   5-10 yrs   Analytics  Delhi NCR  15to25             1989     4
# 12    3-6 yrs   Analytics  Bengaluru    3to6              190     9
#
# ...

# %% [markdown]
# **Create and Delete COlumns**
#
# B. Delete a Column
#
# - if column name exists, then you can delete it, ELSE error
# - dfName.drop( labels, axis = 0, inplace = False)
#
# axis : 0 -> means remove row
# axis : 1 -> means remove column
#
# inplace : True -> Apply the changes permanently to the same dataset
# inplace : False -> Apply the changes to the same dataset
#
# labels -> single name or list of names

# %%
# Remove the row
dataset.drop(2)
# Out:
#    experience   job_desig   location  salary  placement_count  rand  \
# 0     2-4 yrs   Analytics     Mumbai   6to10             4479    64
# 1    5-10 yrs   Analytics  Delhi NCR   6to10             1969    49
# 3     2-6 yrs   Analytics  Bengaluru   6to10              330   100
# 4     6-8 yrs   Analytics  Delhi NCR  25to50             2665   100
# 5     2-5 yrs  Consultant  Bengaluru    3to6              314     1
# 6    5-10 yrs   Analytics    Chennai  10to15             3382    64
# 7    8-13 yrs    Industry    Chennai  15to25             2922    49
# 8    5-10 yrs        Data  Bengaluru  15to25             2807   100
# 9    6-11 yrs        Data     Mumbai   6to10             1176    49
# 10    0-3 yrs    Business  Bengaluru    3to6              107     1
# 11   5-10 yrs   Analytics  Delhi NCR  15to25             1989     4
# 12    3-6 yrs   Analytics  Bengaluru    3to6              190     9
#
#     new placement count
# 0                4031.1
# 1                1772.1
# ...

# %%
# Remove the column
# dataset.drop("rand", axis = 1) # inplace = True to make it permanent
dataset.drop(["rand", "location", 'salary'], axis = 1) # inplace = True to make it permanent
# Out:
#    experience   job_desig  placement_count  new placement count
# 0     2-4 yrs   Analytics             4479               4031.1
# 1    5-10 yrs   Analytics             1969               1772.1
# 2     3-8 yrs      Growth             3319               2987.1
# 3     2-6 yrs   Analytics              330                297.0
# 4     6-8 yrs   Analytics             2665               2398.5
# 5     2-5 yrs  Consultant              314                282.6
# 6    5-10 yrs   Analytics             3382               3043.8
# 7    8-13 yrs    Industry             2922               2629.8
# 8    5-10 yrs        Data             2807               2526.3
# 9    6-11 yrs        Data             1176               1058.4
# 10    0-3 yrs    Business              107                 96.3
# 11   5-10 yrs   Analytics             1989               1790.1
# 12    3-6 yrs   Analytics              190                171.0

# %%
dataset
# Out:
#    experience   job_desig   location  salary  placement_count  rand  \
# 0     2-4 yrs   Analytics     Mumbai   6to10             4479    64
# 1    5-10 yrs   Analytics  Delhi NCR   6to10             1969    49
# 2     3-8 yrs      Growth     Mumbai  15to25             3319    36
# 3     2-6 yrs   Analytics  Bengaluru   6to10              330   100
# 4     6-8 yrs   Analytics  Delhi NCR  25to50             2665   100
# 5     2-5 yrs  Consultant  Bengaluru    3to6              314     1
# 6    5-10 yrs   Analytics    Chennai  10to15             3382    64
# 7    8-13 yrs    Industry    Chennai  15to25             2922    49
# 8    5-10 yrs        Data  Bengaluru  15to25             2807   100
# 9    6-11 yrs        Data     Mumbai   6to10             1176    49
# 10    0-3 yrs    Business  Bengaluru    3to6              107     1
# 11   5-10 yrs   Analytics  Delhi NCR  15to25             1989     4
# 12    3-6 yrs   Analytics  Bengaluru    3to6              190     9
#
# ...

# %%
index_column = [f"Row_{i+1}" for i in range( dataset.shape[0] )]
index_column
# Out:
# ['Row_1',
#  'Row_2',
#  'Row_3',
#  'Row_4',
#  'Row_5',
#  'Row_6',
#  'Row_7',
#  'Row_8',
#  'Row_9',
#  'Row_10',
#  'Row_11',
#  'Row_12',
#  'Row_13']

# %%
dataset['Row No'] = index_column   #Create a new column
dataset.set_index("Row No", inplace=True) #Set the index
dataset
# Out:
#        experience   job_desig   location  salary  placement_count  rand  \
# Row No
# Row_1     2-4 yrs   Analytics     Mumbai   6to10             4479    64
# Row_2    5-10 yrs   Analytics  Delhi NCR   6to10             1969    49
# Row_3     3-8 yrs      Growth     Mumbai  15to25             3319    36
# Row_4     2-6 yrs   Analytics  Bengaluru   6to10              330   100
# Row_5     6-8 yrs   Analytics  Delhi NCR  25to50             2665   100
# Row_6     2-5 yrs  Consultant  Bengaluru    3to6              314     1
# Row_7    5-10 yrs   Analytics    Chennai  10to15             3382    64
# Row_8    8-13 yrs    Industry    Chennai  15to25             2922    49
# Row_9    5-10 yrs        Data  Bengaluru  15to25             2807   100
# Row_10   6-11 yrs        Data     Mumbai   6to10             1176    49
# Row_11    0-3 yrs    Business  Bengaluru    3to6              107     1
# Row_12   5-10 yrs   Analytics  Delhi NCR  15to25             1989     4
# ...

# %%
# drop/remove wrt index

dataset.drop( "Row_7", axis = 0)
# Out:
#        experience   job_desig   location  salary  placement_count  rand  \
# Row No
# Row_1     2-4 yrs   Analytics     Mumbai   6to10             4479    64
# Row_2    5-10 yrs   Analytics  Delhi NCR   6to10             1969    49
# Row_3     3-8 yrs      Growth     Mumbai  15to25             3319    36
# Row_4     2-6 yrs   Analytics  Bengaluru   6to10              330   100
# Row_5     6-8 yrs   Analytics  Delhi NCR  25to50             2665   100
# Row_6     2-5 yrs  Consultant  Bengaluru    3to6              314     1
# Row_8    8-13 yrs    Industry    Chennai  15to25             2922    49
# Row_9    5-10 yrs        Data  Bengaluru  15to25             2807   100
# Row_10   6-11 yrs        Data     Mumbai   6to10             1176    49
# Row_11    0-3 yrs    Business  Bengaluru    3to6              107     1
# Row_12   5-10 yrs   Analytics  Delhi NCR  15to25             1989     4
# Row_13    3-6 yrs   Analytics  Bengaluru    3to6              190     9
#
# ...

# %% [markdown]
# ## apply functions
#
# - these are functions that you can apply on the entire columns
# - its a single line functions....
#
# - apply function on single column
# dfName['columnName'].apply(  )
#
# - apply function on more than 1 column
# dfName[['c1', "c2]].apply( , axis = 1 )
#
#
# - just like, map and filter, this will apply the function on each value inside the column. there is  no need to make a loop

# %%
dataset = pd.read_excel("student_placement.xlsx", sheet_name="value_data")
dataset['placement'] = dataset['placement_count'].apply(str)

dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   experience       13 non-null     object
#  1   job_desig        13 non-null     object
#  2   location         13 non-null     object
#  3   salary           13 non-null     object
#  4   placement_count  13 non-null     int64
#  5   placement        13 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 756.0+ bytes

# %%
dataset['placement']
# Out:
# 0     4479
# 1     1969
# 2     3319
# 3      330
# 4     2665
# 5      314
# 6     3382
# 7     2922
# 8     2807
# 9     1176
# 10     107
# 11    1989
# 12     190
# Name: placement, dtype: object

# %%
# dataset['Remarks']

# %%
p = 3319
print( "Good" if p > 2000 else "Bad" )

p = 1112
print( "Good" if p > 2000 else "Bad" )

def remarks(p) : 
    if  p > 2000: return "Good"
    else: return "Bad"
# Out:
# Good
# Bad

# %%
dataset['Remarks'] = dataset['placement_count'].apply( lambda p : "Good" if p > 2000 else "Bad"  )
dataset
# Out:
#    experience   job_desig   location  salary  placement_count placement  \
# 0     2-4 yrs   Analytics     Mumbai   6to10             4479      4479
# 1    5-10 yrs   Analytics  Delhi NCR   6to10             1969      1969
# 2     3-8 yrs      Growth     Mumbai  15to25             3319      3319
# 3     2-6 yrs   Analytics  Bengaluru   6to10              330       330
# 4     6-8 yrs   Analytics  Delhi NCR  25to50             2665      2665
# 5     2-5 yrs  Consultant  Bengaluru    3to6              314       314
# 6    5-10 yrs   Analytics    Chennai  10to15             3382      3382
# 7    8-13 yrs    Industry    Chennai  15to25             2922      2922
# 8    5-10 yrs        Data  Bengaluru  15to25             2807      2807
# 9    6-11 yrs        Data     Mumbai   6to10             1176      1176
# 10    0-3 yrs    Business  Bengaluru    3to6              107       107
# 11   5-10 yrs   Analytics  Delhi NCR  15to25             1989      1989
# ...

# %%
dataset['Remarks'] = dataset['placement_count'].apply( remarks  )
dataset
# Out:
#    experience   job_desig   location  salary  placement_count placement  \
# 0     2-4 yrs   Analytics     Mumbai   6to10             4479      4479
# 1    5-10 yrs   Analytics  Delhi NCR   6to10             1969      1969
# 2     3-8 yrs      Growth     Mumbai  15to25             3319      3319
# 3     2-6 yrs   Analytics  Bengaluru   6to10              330       330
# 4     6-8 yrs   Analytics  Delhi NCR  25to50             2665      2665
# 5     2-5 yrs  Consultant  Bengaluru    3to6              314       314
# 6    5-10 yrs   Analytics    Chennai  10to15             3382      3382
# 7    8-13 yrs    Industry    Chennai  15to25             2922      2922
# 8    5-10 yrs        Data  Bengaluru  15to25             2807      2807
# 9    6-11 yrs        Data     Mumbai   6to10             1176      1176
# 10    0-3 yrs    Business  Bengaluru    3to6              107       107
# 11   5-10 yrs   Analytics  Delhi NCR  15to25             1989      1989
# ...

# %%
map(funName, seqName)

# %%
# create a symbool column
# Mumbai : Mum
# Bengaluru : Ben

# 'Mumbai'[: 3]
dataset['location'].apply( lambda x : str(x)[ : 3] )
# Out:
# 0     Mum
# 1     Del
# 2     Mum
# 3     Ben
# 4     Del
# 5     Ben
# 6     Che
# 7     Che
# 8     Ben
# 9     Mum
# 10    Ben
# 11    Del
# 12    Ben
# Name: location, dtype: object

# %%
# create a symbool column
# Analytics - Mumbai : Ana-Mum
# Consultant - Bengaluru : Con-Ben

dataset[["job_desig", 'location']].apply( lambda a : str(a[0])[ : 3] + "-" + str(a[1])[ : 3], axis = 1  )
# Out:
# 0     Ana-Mum
# 1     Ana-Del
# 2     Gro-Mum
# 3     Ana-Ben
# 4     Ana-Del
# 5     Con-Ben
# 6     Ana-Che
# 7     Ind-Che
# 8     Dat-Ben
# 9     Dat-Mum
# 10    Bus-Ben
# 11    Ana-Del
# 12    Ana-Ben
# dtype: object

# %%
# convert location to uppercase...
# dataset['location'] = dataset['location'].apply(  ) # for Permanenet

dataset['location'].apply( lambda x : str(x).upper() )
# Out:
# 0        MUMBAI
# 1     DELHI NCR
# 2        MUMBAI
# 3     BENGALURU
# 4     DELHI NCR
# 5     BENGALURU
# 6       CHENNAI
# 7       CHENNAI
# 8     BENGALURU
# 9        MUMBAI
# 10    BENGALURU
# 11    DELHI NCR
# 12    BENGALURU
# Name: location, dtype: object

# %%
# x = 'Delhi NCR'
# f1 = lambda x : str(x).upper()

# f1(x)
# Out:
# 'DELHI NCR'

# %%
dataset['location']
# Out:
# 0        Mumbai
# 1     Delhi NCR
# 2        Mumbai
# 3     Bengaluru
# 4     Delhi NCR
# 5     Bengaluru
# 6       Chennai
# 7       Chennai
# 8     Bengaluru
# 9        Mumbai
# 10    Bengaluru
# 11    Delhi NCR
# 12    Bengaluru
# Name: location, dtype: object

# %%
a1 = 'Analytics'
a2 = 'Delhi NCR'

f1 = lambda x, y : str(x)[ : 3] + "-" + str(y)[ : 3] 
f1(a1, a2)
# Out:
# 'Ana-Del'

# %%
a = ['Analytics', 'Delhi NCR']

f1 = lambda a : str(a[0])[ : 3] + "-" + str(a[1])[ : 3] 
f1(a)
# Out:
# 'Ana-Del'

# %%
# readd more than 1 column

df[['location', "salary"]]
# Out:
#       location  salary
# 0       Mumbai   6to10
# 1    Delhi NCR   6to10
# 2       Mumbai  15to25
# 3    Bengaluru   6to10
# 4    Delhi NCR  25to50
# ..         ...     ...
# 100  Bengaluru  15to25
# 101     Mumbai    3to6
# 102  Delhi NCR  25to50
# 103  Bengaluru  15to25
# 104    Chennai  10to15
#
# [105 rows x 2 columns]

# %% [markdown]
# **Slicing : **
#
# - read any cell value inside the tabular format
# - read multiple values also
#
# stringName[start : end]
# listName[start : end]
# tupName[start : end]
#
#
# Slicing wrt to Positions (iloc : index_lock) : end is not included
# dfName.____[rows, columns]
#
# dfName.iloc[start : end, start : end]
# dfName.iloc[ [] , []  ]
#
#
# Slicing wrt to Names (loc : lock) : end is included
# dfName.____[rows, columns]
#
# dfName.loc[ [] , []  ]

# %% [markdown]
# Slicing wrt to Positions (iloc : index_lock)
#
# dfName.____[rows, columns]
#
# dfName.iloc[start : end, start : end]

# %%
dataset = pd.read_excel("student_placement.xlsx", sheet_name="value_data")
dataset
# Out:
#    experience   job_desig   location  salary  placement_count
# 0     2-4 yrs   Analytics     Mumbai   6to10             4479
# 1    5-10 yrs   Analytics  Delhi NCR   6to10             1969
# 2     3-8 yrs      Growth     Mumbai  15to25             3319
# 3     2-6 yrs   Analytics  Bengaluru   6to10              330
# 4     6-8 yrs   Analytics  Delhi NCR  25to50             2665
# 5     2-5 yrs  Consultant  Bengaluru    3to6              314
# 6    5-10 yrs   Analytics    Chennai  10to15             3382
# 7    8-13 yrs    Industry    Chennai  15to25             2922
# 8    5-10 yrs        Data  Bengaluru  15to25             2807
# 9    6-11 yrs        Data     Mumbai   6to10             1176
# 10    0-3 yrs    Business  Bengaluru    3to6              107
# 11   5-10 yrs   Analytics  Delhi NCR  15to25             1989
# 12    3-6 yrs   Analytics  Bengaluru    3to6              190

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print( dataset.iloc[ 3 : 8, 2 : 4 ] )
print()
print( dataset.loc[ [3 , 4 , 5 , 6 , 7], ['location', 'salary'] ] )
# Out:
#     location  salary
# 3  Bengaluru   6to10
# 4  Delhi NCR  25to50
# 5  Bengaluru    3to6
# 6    Chennai  10to15
# 7    Chennai  15to25
#
#     location  salary
# 3  Bengaluru   6to10
# 4  Delhi NCR  25to50
# 5  Bengaluru    3to6
# 6    Chennai  10to15
# 7    Chennai  15to25

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print( dataset.iloc[ 1 , 3 : ].values )
# dataset.iloc[ 1 , 3 : ]
print()
print( dataset.loc[ 1 , ['salary', 'placement_count'] ].values )
# Out:
# ['6to10' 1969]
#
# ['6to10' 1969]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print( dataset.iloc[ [2 , 5 , 8 , 9 , 12] , [1 , 4] ] )
print()
print( dataset.loc[ [2 , 5 , 8 , 9 , 12] , ['job_desig', 'placement_count'] ] )
# Out:
#      job_desig  placement_count
# 2       Growth             3319
# 5   Consultant              314
# 8         Data             2807
# 9         Data             1176
# 12   Analytics              190
#
#      job_desig  placement_count
# 2       Growth             3319
# 5   Consultant              314
# 8         Data             2807
# 9         Data             1176
# 12   Analytics              190

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print( dataset.iloc[ : , [0 , 2]] )
print()
print( dataset.loc[ : , ['experience' , 'location']] )
# Out:
#    experience   location
# 0     2-4 yrs     Mumbai
# 1    5-10 yrs  Delhi NCR
# 2     3-8 yrs     Mumbai
# 3     2-6 yrs  Bengaluru
# 4     6-8 yrs  Delhi NCR
# 5     2-5 yrs  Bengaluru
# 6    5-10 yrs    Chennai
# 7    8-13 yrs    Chennai
# 8    5-10 yrs  Bengaluru
# 9    6-11 yrs     Mumbai
# 10    0-3 yrs  Bengaluru
# 11   5-10 yrs  Delhi NCR
# 12    3-6 yrs  Bengaluru
#
#    experience   location
# 0     2-4 yrs     Mumbai
# 1    5-10 yrs  Delhi NCR
# 2     3-8 yrs     Mumbai
# 3     2-6 yrs  Bengaluru
# 4     6-8 yrs  Delhi NCR
# 5     2-5 yrs  Bengaluru
# 6    5-10 yrs    Chennai
# 7    8-13 yrs    Chennai
# 8    5-10 yrs  Bengaluru
# 9    6-11 yrs     Mumbai
# 10    0-3 yrs  Bengaluru
# 11   5-10 yrs  Delhi NCR
# 12    3-6 yrs  Bengaluru

# %%
new_data = dataset.copy()

new_data['Row No'] = index_column   #Create a new column
new_data.set_index("Row No", inplace=True) #Set the index
new_data
# Out:
#        experience   job_desig   location  salary  placement_count
# Row No
# Row_1     2-4 yrs   Analytics     Mumbai   6to10             4479
# Row_2    5-10 yrs   Analytics  Delhi NCR   6to10             1969
# Row_3     3-8 yrs      Growth     Mumbai  15to25             3319
# Row_4     2-6 yrs   Analytics  Bengaluru   6to10              330
# Row_5     6-8 yrs   Analytics  Delhi NCR  25to50             2665
# Row_6     2-5 yrs  Consultant  Bengaluru    3to6              314
# Row_7    5-10 yrs   Analytics    Chennai  10to15             3382
# Row_8    8-13 yrs    Industry    Chennai  15to25             2922
# Row_9    5-10 yrs        Data  Bengaluru  15to25             2807
# Row_10   6-11 yrs        Data     Mumbai   6to10             1176
# Row_11    0-3 yrs    Business  Bengaluru    3to6              107
# Row_12   5-10 yrs   Analytics  Delhi NCR  15to25             1989
# Row_13    3-6 yrs   Analytics  Bengaluru    3to6              190

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print( new_data.iloc[ [1, 7, 11] , :  ] )
print()
print( new_data.loc[ ["Row_2", "Row_8", "Row_12"] , :  ] )
# Out:
#        experience  job_desig   location  salary  placement_count
# Row No
# Row_2    5-10 yrs  Analytics  Delhi NCR   6to10             1969
# Row_8    8-13 yrs   Industry    Chennai  15to25             2922
# Row_12   5-10 yrs  Analytics  Delhi NCR  15to25             1989
#
#        experience  job_desig   location  salary  placement_count
# Row No
# Row_2    5-10 yrs  Analytics  Delhi NCR   6to10             1969
# Row_8    8-13 yrs   Industry    Chennai  15to25             2922
# Row_12   5-10 yrs  Analytics  Delhi NCR  15to25             1989

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print( new_data.iloc[ [4 , 6] , [0 , 2]  ] )
print()
print( new_data.loc[ ["Row_5", "Row_7"] , ['experience', "location"]  ] )
# Out:
#        experience   location
# Row No
# Row_5     6-8 yrs  Delhi NCR
# Row_7    5-10 yrs    Chennai
#
#        experience   location
# Row No
# Row_5     6-8 yrs  Delhi NCR
# Row_7    5-10 yrs    Chennai

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print( new_data.iloc[ [1 ,11] , 1 : 3  ] )
print()
print( new_data.loc[ ["Row_2", "Row_12"] , ['job_desig', "location"]  ] )
# Out:
#         job_desig   location
# Row No
# Row_2   Analytics  Delhi NCR
# Row_12  Analytics  Delhi NCR
#
#         job_desig   location
# Row No
# Row_2   Analytics  Delhi NCR
# Row_12  Analytics  Delhi NCR

# %% [markdown]
# ## Filtering the records
#
# - making a query...
# - dfName[ query ]
#
# - dfName[ dfName[columnName] ]
#
# - dfName[ ( dfName[columnName] EXP ) and ( dfName[columnName] EXP) or ( dfName[columnName] EXP) ]

# %%
df = pd.read_excel("student_placement.xlsx")
df.head()
# Out:
#   experience  job_desig   location  salary  placement_count
# 0    2-4 yrs  Analytics     Mumbai   6to10             4479
# 1   5-10 yrs  Analytics  Delhi NCR   6to10             1969
# 2    3-8 yrs     Growth     Mumbai  15to25             3319
# 3    2-6 yrs  Analytics  Bengaluru   6to10              330
# 4    6-8 yrs  Analytics  Delhi NCR  25to50             2665

# %%
# extract all the records where placement count is more than 4000...

print( ( df['placement_count'] > 4000 ).sum() )

result_df = df[ df['placement_count'] > 4000  ]  # Where QUERY is TRUE, fetch me those records from the df
result_df
# Out:
# 11
#    experience   job_desig   location  salary  placement_count
# 0     2-4 yrs   Analytics     Mumbai   6to10             4479
# 18    2-7 yrs   Analytics     Mumbai  15to25             4167
# 20    1-5 yrs      Senior     Mumbai   6to10             4448
# 29    2-5 yrs      Senior     Mumbai    3to6             4011
# 36    4-9 yrs  Consultant     Mumbai  15to25             5018
# 46   8-10 yrs   Analytics  Bengaluru  10to15             4541
# 52    4-8 yrs   Analytics     Mumbai   6to10             4840
# 56   5-10 yrs        Data     Mumbai    3to6             4568
# 65   8-12 yrs   Analytics  Delhi NCR  25to50             4470
# 71    3-8 yrs   Analytics  Delhi NCR   6to10             4330
# 95    3-5 yrs        Data     Mumbai  10to15             4904

# %%
print( type(df) )
print( type(result_df) )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
word = "new delhi"
print(type( word ) )
print(type( word[ : 3] ) )
# Out:
# <class 'str'>
# <class 'str'>

# %%
# extract all the INDEXES where placement count is more than 4000...

result_df = df[ df['placement_count'] > 4000  ]
print( result_df )
print( result_df.index )

print( df[ df['placement_count'] > 4000  ].index )
# Out:
#    experience   job_desig   location  salary  placement_count
# 0     2-4 yrs   Analytics     Mumbai   6to10             4479
# 18    2-7 yrs   Analytics     Mumbai  15to25             4167
# 20    1-5 yrs      Senior     Mumbai   6to10             4448
# 29    2-5 yrs      Senior     Mumbai    3to6             4011
# 36    4-9 yrs  Consultant     Mumbai  15to25             5018
# 46   8-10 yrs   Analytics  Bengaluru  10to15             4541
# 52    4-8 yrs   Analytics     Mumbai   6to10             4840
# 56   5-10 yrs        Data     Mumbai    3to6             4568
# 65   8-12 yrs   Analytics  Delhi NCR  25to50             4470
# 71    3-8 yrs   Analytics  Delhi NCR   6to10             4330
# 95    3-5 yrs        Data     Mumbai  10to15             4904
# Index([0, 18, 20, 29, 36, 46, 52, 56, 65, 71, 95], dtype='int64')
# Index([0, 18, 20, 29, 36, 46, 52, 56, 65, 71, 95], dtype='int64')

# %%
word = "  new delhi   "
print(word ) 
print(word.upper().strip() ) 

print(word.upper().strip().split(" ")[1] ) 

print( "n" in word )
# Out:
#   new delhi
# NEW DELHI
# DELHI
# True

# %%
# extract all the INDEXES where placement count is more than 4000. display thge location and expereince for them

result_df = df[ df['placement_count'] > 4000  ]
print( result_df )
print()
print( result_df[['location', 'experience']] )
print()
print( df[ df['placement_count'] > 4000  ][['location', 'experience']] )
# Out:
#    experience   job_desig   location  salary  placement_count
# 0     2-4 yrs   Analytics     Mumbai   6to10             4479
# 18    2-7 yrs   Analytics     Mumbai  15to25             4167
# 20    1-5 yrs      Senior     Mumbai   6to10             4448
# 29    2-5 yrs      Senior     Mumbai    3to6             4011
# 36    4-9 yrs  Consultant     Mumbai  15to25             5018
# 46   8-10 yrs   Analytics  Bengaluru  10to15             4541
# 52    4-8 yrs   Analytics     Mumbai   6to10             4840
# 56   5-10 yrs        Data     Mumbai    3to6             4568
# 65   8-12 yrs   Analytics  Delhi NCR  25to50             4470
# 71    3-8 yrs   Analytics  Delhi NCR   6to10             4330
# 95    3-5 yrs        Data     Mumbai  10to15             4904
#
#      location experience
# 0      Mumbai    2-4 yrs
# 18     Mumbai    2-7 yrs
# 20     Mumbai    1-5 yrs
# 29     Mumbai    2-5 yrs
# 36     Mumbai    4-9 yrs
# 46  Bengaluru   8-10 yrs
# 52     Mumbai    4-8 yrs
# ...

# %%
# extract all the INDEXES where placement count is more than 4000. 
# display thge location and expereince for them
# fetch top 4 records

result_df = df[ df['placement_count'] > 4000  ]
print( result_df[['location', 'experience']].head(4) )
print()
print( df[ df['placement_count'] > 4000  ][['location', 'experience']].head(4) )
# Out:
#    location experience
# 0    Mumbai    2-4 yrs
# 18   Mumbai    2-7 yrs
# 20   Mumbai    1-5 yrs
# 29   Mumbai    2-5 yrs
#
#    location experience
# 0    Mumbai    2-4 yrs
# 18   Mumbai    2-7 yrs
# 20   Mumbai    1-5 yrs
# 29   Mumbai    2-5 yrs

# %%
# fetch all the records where location is 'Mumbai' ???

result_df = df[ df['location'] == "Mumbai"  ]
print(result_df.head())
print( result_df.shape )
print( df[ df['location'] == "Mumbai"  ].shape )
# Out:
#    experience   job_desig location  salary  placement_count
# 0     2-4 yrs   Analytics   Mumbai   6to10             4479
# 2     3-8 yrs      Growth   Mumbai  15to25             3319
# 9    6-11 yrs        Data   Mumbai   6to10             1176
# 18    2-7 yrs   Analytics   Mumbai  15to25             4167
# 19    2-4 yrs  Consultant   Mumbai  15to25             3383
# (28, 5)
# (28, 5)

# %%
 df['location'] == "Mumbai"
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 100    False
# 101     True
# 102    False
# 103    False
# 104    False
# Name: location, Length: 105, dtype: bool

# %%
# fetch all the records where location is 'Mumbai' and placement count is more than 4000 ???

# df[ df['placement_count'] > 4000 & df['location'] == "Mumbai"  ]

df[ ( df['placement_count'] > 4000 ) & ( df['location'] == "Mumbai"  ) ]
# Out:
#    experience   job_desig location  salary  placement_count
# 0     2-4 yrs   Analytics   Mumbai   6to10             4479
# 18    2-7 yrs   Analytics   Mumbai  15to25             4167
# 20    1-5 yrs      Senior   Mumbai   6to10             4448
# 29    2-5 yrs      Senior   Mumbai    3to6             4011
# 36    4-9 yrs  Consultant   Mumbai  15to25             5018
# 52    4-8 yrs   Analytics   Mumbai   6to10             4840
# 56   5-10 yrs        Data   Mumbai    3to6             4568
# 95    3-5 yrs        Data   Mumbai  10to15             4904

# %%
# print( 10 < 20 and 5 == 5 )
# Out:
# True

# %%
# fetch all the records where location is 'Mumbai' or job is consulant

res = df[  ( df['location'] == "Mumbai" ) | ( df['job_desig'] == "Consultant" )  ]
print(res)
print(res.shape)
# Out:
#     experience   job_desig   location  salary  placement_count
# 0      2-4 yrs   Analytics     Mumbai   6to10             4479
# 2      3-8 yrs      Growth     Mumbai  15to25             3319
# 5      2-5 yrs  Consultant  Bengaluru    3to6              314
# 9     6-11 yrs        Data     Mumbai   6to10             1176
# 18     2-7 yrs   Analytics     Mumbai  15to25             4167
# 19     2-4 yrs  Consultant     Mumbai  15to25             3383
# 20     1-5 yrs      Senior     Mumbai   6to10             4448
# 21     2-5 yrs  Consultant  Bengaluru    3to6             1473
# 22     2-5 yrs   Analytics     Mumbai  10to15             3848
# 24     0-0 yrs   Analytics     Mumbai    0to3             1167
# 29     2-5 yrs      Senior     Mumbai    3to6             4011
# 30     2-7 yrs   Analytics     Mumbai  10to15             3838
# 34     2-5 yrs     Program     Mumbai    3to6              190
# 36     4-9 yrs  Consultant     Mumbai  15to25             5018
# ...

# %%
# fetch all the records where location is 'Mumbai' or "Bengaluru"

# x == "Mumbai" ??
# x in [ 'Mumbai', "Bengaluru" ] # Membership operator

r1 = df[  ( df['location'] == "Mumbai" ) | ( df['location'] == "Bengaluru" )  ]
r2 = df[   df['location'].isin([ 'Mumbai', "Bengaluru" ] )   ] # DataFrame Membership operator

print(r1.shape)
print(r2.shape)
# Out:
# (61, 5)
# (61, 5)

# %% [markdown]
# ## sort_values()
#
# - sorts the dataset on the basis of the column

# %%
df = pd.read_excel("student_placement.xlsx")
df.head()
# Out:
#   experience  job_desig   location  salary  placement_count
# 0    2-4 yrs  Analytics     Mumbai   6to10             4479
# 1   5-10 yrs  Analytics  Delhi NCR   6to10             1969
# 2    3-8 yrs     Growth     Mumbai  15to25             3319
# 3    2-6 yrs  Analytics  Bengaluru   6to10              330
# 4    6-8 yrs  Analytics  Delhi NCR  25to50             2665

# %%
df.sort_values(by = ['location']).tail()
# Out:
#    experience  job_desig location  salary  placement_count
# 62    3-8 yrs   Business   Mumbai  15to25             2809
# 68    2-5 yrs    Program   Mumbai    3to6              190
# 72   5-10 yrs       Data   Mumbai    3to6             1831
# 34    2-5 yrs    Program   Mumbai    3to6              190
# 52    4-8 yrs  Analytics   Mumbai   6to10             4840

# %%
df.sort_values(by = ['location']).head()
# Out:
#    experience job_desig   location  salary  placement_count
# 41    1-4 yrs    Social  Ahmedabad    0to3             2682
# 42    1-6 yrs      Data  Ahmedabad    0to3             3914
# 59    1-5 yrs      Data  Ahmedabad    3to6             3365
# 96   7-11 yrs      Data  Ahmedabad  10to15             1301
# 25    0-3 yrs       SEO  Ahmedabad    3to6             1248

# %%
df.sort_values(by = ['location'], ascending=False)
# Out:
#    experience  job_desig   location  salary  placement_count
# 0     2-4 yrs  Analytics     Mumbai   6to10             4479
# 22    2-5 yrs  Analytics     Mumbai  10to15             3848
# 29    2-5 yrs     Senior     Mumbai    3to6             4011
# 30    2-7 yrs  Analytics     Mumbai  10to15             3838
# 34    2-5 yrs    Program     Mumbai    3to6              190
# ..        ...        ...        ...     ...              ...
# 42    1-6 yrs       Data  Ahmedabad    0to3             3914
# 41    1-4 yrs     Social  Ahmedabad    0to3             2682
# 96   7-11 yrs       Data  Ahmedabad  10to15             1301
# 59    1-5 yrs       Data  Ahmedabad    3to6             3365
# 25    0-3 yrs        SEO  Ahmedabad    3to6             1248
#
# [105 rows x 5 columns]

# %%
df.sort_values(by = ['location', "job_desig"])
# Out:
#    experience job_desig   location  salary  placement_count
# 42    1-6 yrs      Data  Ahmedabad    0to3             3914
# 59    1-5 yrs      Data  Ahmedabad    3to6             3365
# 96   7-11 yrs      Data  Ahmedabad  10to15             1301
# 25    0-3 yrs       SEO  Ahmedabad    3to6             1248
# 41    1-4 yrs    Social  Ahmedabad    0to3             2682
# ..        ...       ...        ...     ...              ...
# 76    0-2 yrs    Hiring     Mumbai    0to3              921
# 34    2-5 yrs   Program     Mumbai    3to6              190
# 68    2-5 yrs   Program     Mumbai    3to6              190
# 20    1-5 yrs    Senior     Mumbai   6to10             4448
# 29    2-5 yrs    Senior     Mumbai    3to6             4011
#
# [105 rows x 5 columns]

# %%
df.sort_values(by = ['location', "job_desig"], ascending=[True, False])
# Out:
#     experience  job_desig   location  salary  placement_count
# 41     1-4 yrs     Social  Ahmedabad    0to3             2682
# 25     0-3 yrs        SEO  Ahmedabad    3to6             1248
# 42     1-6 yrs       Data  Ahmedabad    0to3             3914
# 59     1-5 yrs       Data  Ahmedabad    3to6             3365
# 96    7-11 yrs       Data  Ahmedabad  10to15             1301
# ..         ...        ...        ...     ...              ...
# 52     4-8 yrs  Analytics     Mumbai   6to10             4840
# 77   15-25 yrs  Analytics     Mumbai  25to50              322
# 83     4-8 yrs  Analytics     Mumbai    3to6             3767
# 98     4-9 yrs  Analytics     Mumbai  10to15             1863
# 101    4-8 yrs  Analytics     Mumbai    3to6             3767
#
# [105 rows x 5 columns]
